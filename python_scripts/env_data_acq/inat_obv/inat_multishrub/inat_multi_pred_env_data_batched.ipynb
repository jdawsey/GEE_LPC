# %% [markdown]
# # Necessary to check that the functions are all still relevant

# %%
import ee
import geemap
import json
import os
import sys
from geemap import geojson_to_ee
from ipyleaflet import GeoJSON
sys.path.insert(1, 'D:/!!Research/rgee_test/GEE_LPC/python_scripts')
#sys.path.insert(1, 'C:/Users/Justin-Laptop/Documents/Research/GEE_LPC/python_scripts')
from my_gee_functions import file_address_func
from my_gee_functions import ee_list_func
from my_gee_functions import stdrd_func

# %%
# Authenticate if needed
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
#Initializing the ee project

ee.Initialize(project = 'ee-jdawsey')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Actually pulling the data
#
# For polaris: Can choose from 0_5, 5_15, 15_30, 30_60, 60_100, 100_200\
# Don't need to run most of below chunks if planning to pull en mass

# %%
shrubs_state = 'texas'
state_abbrev = 'TX'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bd_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_0_5')
bd_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_5_15')
bd_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_15_30')
bd_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_30_60')
bd_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_60_100')
bd_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_100_200')

bd_env_bands = ee.Image([bd_0_5, bd_5_15, bd_15_30, bd_30_60, bd_60_100, bd_100_200])
bd_env_bands = bd_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
bd_env_bands = bd_env_bands.rename('bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200')
#print(bd_env_bands.bandNames().getInfo())

clay_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_0_5')
clay_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_5_15')
clay_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_15_30')
clay_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_30_60')
clay_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_60_100')
clay_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_100_200')

clay_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
clay_env_bands = clay_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
clay_env_bands = clay_env_bands.rename('clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200')
#print(clay_env_bands.bandNames().getInfo())

ksat_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_0_5')
ksat_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_5_15')
ksat_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_15_30')
ksat_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_30_60')
ksat_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_60_100')
ksat_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_100_200')

ksat_env_bands = ee.Image([ksat_0_5, ksat_5_15, ksat_15_30, ksat_30_60, ksat_60_100, ksat_100_200])
ksat_env_bands = ksat_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
ksat_env_bands = ksat_env_bands.rename('ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200')
#print(ksat_env_bands.bandNames().getInfo())

om_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_0_5')
om_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_5_15')
om_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_15_30')
om_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_30_60')
om_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_60_100')
om_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_100_200')

om_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
om_env_bands = om_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
om_env_bands = om_env_bands.rename('om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200')
#print(om_env_bands.bandNames().getInfo())

ph_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_0_5')
ph_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_5_15')
ph_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_15_30')
ph_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_30_60')
ph_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_60_100')
ph_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_100_200')

ph_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
ph_env_bands = ph_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
ph_env_bands = ph_env_bands.rename('ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200')
#print(ph_env_bands.bandNames().getInfo())

sand_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_0_5')
sand_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_5_15')
sand_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_15_30')
sand_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_30_60')
sand_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_60_100')
sand_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_100_200')

sand_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
sand_env_bands = sand_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
sand_env_bands = sand_env_bands.rename('sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200')
#print(sand_env_bands.bandNames().getInfo())

silt_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_0_5')
silt_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_5_15')
silt_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_15_30')
silt_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_30_60')
silt_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_60_100')
silt_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_100_200')

silt_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
silt_env_bands = silt_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
silt_env_bands = silt_env_bands.rename('silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200')
#print(silt_env_bands.bandNames().getInfo())

theta_r_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_0_5')
theta_r_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_5_15')
theta_r_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_15_30')
theta_r_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_30_60')
theta_r_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_60_100')
theta_r_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_100_200')

theta_r_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
theta_r_env_bands = theta_r_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
theta_r_env_bands = theta_r_env_bands.rename('theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200')
#print(theta_r_env_bands.bandNames().getInfo())

theta_s_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_0_5')
theta_s_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_5_15')
theta_s_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_15_30')
theta_s_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_30_60')
theta_s_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_60_100')
theta_s_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_100_200')

theta_s_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
theta_s_env_bands = theta_s_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
theta_s_env_bands = theta_s_env_bands.rename('theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200')
#print(theta_s_env_bands.bandNames().getInfo())

polaris_bands = ee.Image([bd_env_bands, 
                           clay_env_bands, 
                           ksat_env_bands, 
                           om_env_bands, 
                           ph_env_bands, 
                           sand_env_bands,
                           silt_env_bands,
                           theta_r_env_bands,
                           theta_s_env_bands])
print(polaris_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %%
caco3 = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/caco3')
caco3 = caco3.select(['b1'])
caco3 = caco3.resample('bicubic').reproject('EPSG:4326', scale = 30)
caco3 = caco3.rename('caco3')
#print(caco3.bandNames().getInfo())

cec = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/cec')
cec = cec.select(['b1'])
cec = cec.resample('bicubic').reproject('EPSG:4326', scale = 30)
cec = cec.rename('cec')

ec = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/ec')
ec = ec.select(['b1'])
ec = ec.resample('bicubic').reproject('EPSG:4326', scale = 30)
ec = ec.rename('ec')

sar = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/sar')
sar = sar.select(['b1'])
sar = sar.resample('bicubic').reproject('EPSG:4326', scale = 30)
sar = sar.rename('sar')

kw_025 = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/kw_025')
kw_025 = kw_025.select(['b1'])
kw_025 = kw_025.resample('bicubic').reproject('EPSG:4326', scale = 30)
kw_025 = kw_025.rename('kw_025')

#lcc_i = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/lcc_i')
#lcc_i = lcc_i.select(['b1'])
#lcc_i = lcc_i.resample('bicubic').reproject('EPSG:4326', scale = 30)
#lcc_i = lcc_i.rename('lcc_i')

#lcc_ni = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/lcc_ni')
#lcc_ni = lcc_ni.select(['b1'])
#lcc_ni = lcc_ni.resample('bicubic').reproject('EPSG:4326', scale = 30)
#lcc_ni = lcc_ni.rename('lcc_ni')

resdept = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/resdept')
resdept = resdept.select(['b1'])
resdept = resdept.resample('bicubic').reproject('EPSG:4326', scale = 30)
resdept = resdept.rename('resdept')

soil_depth = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/soil_depth')
soil_depth = soil_depth.select(['b1'])
soil_depth = soil_depth.resample('bicubic').reproject('EPSG:4326', scale = 30)
soil_depth = soil_depth.rename('soil_depth')

#soil_temp_regime = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/soil_temp_regime')
#soil_temp_regime = soil_temp_regime.select(['b1'])
#soil_temp_regime = soil_temp_regime.resample('bicubic').reproject('EPSG:4326', scale = 30)
#soil_temp_regime = soil_temp_regime.rename('soil_temp_regime')

wind_erodibility_index = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/wind_erodibility_index')
wind_erodibility_index = wind_erodibility_index.select(['b1'])
wind_erodibility_index = wind_erodibility_index.resample('bicubic').reproject('EPSG:4326', scale = 30)
wind_erodibility_index = wind_erodibility_index.rename('wind_erodibility_index')

rf_025 = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/physical/rf_025')
rf_025 = rf_025.select(['b1'])
rf_025 = rf_025.resample('bicubic').reproject('EPSG:4326', scale = 30)
rf_025 = rf_025.rename('rf_025')

water_storage = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/physical/water_storage')
water_storage = water_storage.select(['b1'])
water_storage = water_storage.resample('bicubic').reproject('EPSG:4326', scale = 30)
water_storage = water_storage.rename('water_storage')


uc_soil_bands = ee.Image([ caco3, 
                           cec, 
                           ec, 
                           sar, 
                           kw_025,
                           #lcc_i,
                           #lcc_ni,
                           resdept,
                           soil_depth,
                           #soil_temp_regime,
                           wind_erodibility_index,
                           rf_025,
                           water_storage])
print(uc_soil_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['caco3', 'cec', 'ec', 'sar', 'kw_025', 'resdept', 'soil_depth', 'wind_erodibility_index', 'rf_025', 'water_storage']

# %%
bioclim = ee.Image('WORLDCLIM/V1/BIO')
ann_rain = bioclim.select(['bio12'])
#bioclim_proj = ann_rain.projection().getInfo()
#bioclim_crs = bioclim_proj['crs']
ann_rain = ann_rain.resample('bicubic').reproject('EPSG:4326', scale = 30)

temp_range = bioclim.select(['bio07'])
temp_range = temp_range.resample('bicubic').reproject('EPSG:4326', scale = 30)

bioclim_bands = ee.Image([ann_rain, temp_range])
print(bioclim_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['bio12', 'bio07']

# %% [markdown]
# Alabama 	AL 	    Kentucky 	KY 	    Ohio 	OH
#                     Louisiana 	LA 	    Oklahoma 	OK
# Arizona 	AZ 	    Maine 	ME 	        Oregon 	OR
# Arkansas 	AR 	    Maryland 	MD 	    Pennsylvania 	PA
#                     Massachusetts 	MA
# California 	CA 	    Michigan 	MI 	    Rhode Island 	RI
# Colorado 	CO 	    Minnesota 	MN 	    South Carolina 	SC
# Connecticut 	CT 	Mississippi 	MS 	South Dakota 	SD
# Delaware 	DE 	    Missouri 	MO 	    Tennessee 	TN
#                     Montana 	MT 	    Texas 	TX
# Florida 	FL 	    Nebraska 	NE
# Georgia 	GA 	    Nevada 	NV 	        Utah 	UT
#                     New Hampshire 	NH 	Vermont 	VT
#                     New Jersey 	NJ 	    Virginia 	VA
# Idaho 	ID 	        New Mexico 	NM      Washinton DC DC
# Illinois 	IL 	    New York 	NY 	    Washington 	WA
# Indiana 	IN 	    North Carolina 	NC 	West Virginia 	WV
# Iowa 	IA 	        North Dakota 	ND 	Wisconsin 	WI
# Kansas 	KS 	                            Wyoming 	WY

# %%
# dist drainages...
nhd_area = ee.FeatureCollection("projects/sat-io/open-datasets/NHD/NHD_TX/NHDArea")
nhd_flowline = ee.FeatureCollection("projects/sat-io/open-datasets/NHD/NHD_TX/NHDFlowline")
nhd = nhd_area.merge(nhd_flowline)

dist_nhd = nhd.distance(searchRadius=50000, maxError=50)
#dist_nhd = dist_nhd.clip(ee_items[num]) #change clip area
dist_nhd = dist_nhd.select(['distance'])
dist_nhd = dist_nhd.rename('dist_drain')
#print(dist_nhd.bandNames().getInfo())

#Dist roads...

#roads = ee.FeatureCollection('TIGER/2016/Roads')
#dist_roads = roads.distance(searchRadius=50000, maxError=50)
#dist_roads = dist_roads.select(['distance'])
#dist_roads = dist_roads.rename('dist_road')
#print(dist_roads.bandNames().getInfo())


#dist_from_bands = ee.Image([dist_nhd, dist_roads])
dist_from_bands = ee.Image([dist_nhd])
print(dist_from_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['dist_drain']

# %%
elevation_data = ee.Image('USGS/3DEP/10m')
elevation = elevation_data.select(['elevation'])
elevation = elevation.rename('elevation')

slope = ee.Terrain.slope(elevation)
slope = slope.select(['slope'])
slope = slope.rename('slope')
#print(slope.bandNames().getInfo())

aspect = ee.Terrain.aspect(elevation)
aspect = aspect.select(['aspect'])
aspect = aspect.rename('aspect')

dem_bands = ee.Image([elevation, slope, aspect])
print(dem_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['elevation', 'slope', 'aspect']

# %%
points_data = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{shrubs_state}_shrubs')

#Map.addLayer(points_data, {}, 'points_data')
#Map.addLayer(buffer, {}, 'buffer')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Select which bands are being pulled so can name batches appropriately.

# %%
#bands_pulling = 'polaris_bands'
#bands_pulling = 'uc_soil_bands'
#bands_pulling = 'bioclim_bands'
bands_pulling = 'dist_from_bands'
#bands_pulling = 'dem_bands'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Define the batch size
batch_size = 2500

# Get the total number of features
num_features = points_data.size().getInfo()

# Calculate the number of batches
num_batches = num_features // batch_size
if num_features % batch_size != 0:
    num_batches += 1

# Define a function to process each batch and export as CSV
def process_batch(start_index, batch_num):
    # Calculate the end index of the batch
    end_index = start_index + batch_size
    if end_index > num_features:
        end_index = num_features
    
    # Get the features for the current batch
    batch_features = points_data.toList(batch_size, start_index)
    
    # Create a feature collection for the batch
    batch_fc = ee.FeatureCollection(batch_features)
    
    # then exporting the data as a csv so that can be used in the xgb algorithm
    work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{state_abbrev.lower()}_batches/{bands_pulling}'
    #work_dir = f'C:/Users/Justin-Laptop/Documents/Research/GEE_LPC/point_data/inat_mesq_obsv/inat_points_env_data/env_batch_csv'
    out_csv = os.path.join(work_dir, f'{shrubs_state}_shrubs_{bands_pulling}_batch_{batch_num}_env_data.csv')
    
    #change depending on the bands being pulled
    geemap.extract_values_to_points(batch_fc, dist_from_bands, out_csv)

# Iterate over batches and process each one
for i in range(num_batches):
    process_batch(i * batch_size, i+1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ...

# %% [markdown]
# ### For pulling multiple states at one time

# %%
#shrubs_states = ['california', 'kansas', 'new_mexico', 'nevada', 'texas']
#sts_abbvs = ['CA', 'KS', 'NM', 'NV', 'TX']
shrubs_states = ['kansas', 'new_mexico', 'nevada', ]
sts_abbvs = ['KS', 'NM', 'NV']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
for ind in range(len(shrubs_states)):
    points_datas = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{shrubs_states[ind]}_shrubs')
    
    # dist drainages...
    nhd_area = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{sts_abbvs[ind]}/NHDArea')
    nhd_flowline = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{sts_abbvs[ind]}/NHDFlowline')
    nhd = nhd_area.merge(nhd_flowline)
    dist_nhd = nhd.distance(searchRadius=50000)
    #dist_nhd = dist_nhd.clip(ee_items[num]) #change clip area
    dist_nhd = dist_nhd.select(['distance'])
    dist_nhd = dist_nhd.rename('dist_drain')
    dist_nhd = dist_nhd.reproject('EPSG:4326', scale = 1)
    #print(dist_nhd.bandNames().getInfo())
    #Dist roads...
    roads = ee.FeatureCollection('TIGER/2016/Roads')
    dist_roads = roads.distance(searchRadius=50000)
    dist_roads = dist_roads.select(['distance'])
    dist_roads = dist_roads.rename('dist_road')
    dist_roads = dist_roads.reproject('EPSG:4326', scale = 1)
    #print(dist_roads.bandNames().getInfo())
    dist_from_bands = ee.Image([dist_nhd, dist_roads])
    print(dist_from_bands.bandNames().getInfo())

    #bands_to_pull = [polaris_bands, uc_soil_bands, bioclim_bands, dist_from_bands, dem_bands]
    #bands_name = ['polaris_bands', 'uc_soil_bands', 'bioclim_bands', 'dist_from_bands', 'dem_bands']
    bands_to_pull = [dist_from_bands]
    bands_name = ['dist_from_bands']
    
    for inde in range(len(bands_to_pull)):
        # Define the batch size
        batch_size = 100
        
        # Get the total number of features
        num_features = points_datas.size().getInfo()
        
        # Calculate the number of batches
        num_batches = num_features // batch_size
        if num_features % batch_size != 0:
            num_batches += 1
        
        # Define a function to process each batch and export as CSV
        def process_batch(start_index, batch_num):
            # Calculate the end index of the batch
            end_index = start_index + batch_size
            if end_index > num_features:
                end_index = num_features
            
            # Get the features for the current batch
            batch_features = points_datas.toList(batch_size, start_index)
            
            # Create a feature collection for the batch
            batch_fc = ee.FeatureCollection(batch_features)
            
            # then exporting the data as a csv so that can be used in the xgb algorithm
            work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{sts_abbvs[ind].lower()}_batches/{bands_name[inde]}'
            #work_dir = f'C:/Users/Justin-Laptop/Documents/Research/GEE_LPC/point_data/inat_mesq_obsv/inat_points_env_data/env_batch_csv'
            out_csv = os.path.join(work_dir, f'{shrubs_states[ind]}_shrubs_{bands_name[inde]}_batch_{batch_num}_env_data.csv')
            
            #change depending on the bands being pulled
            geemap.extract_values_to_points(batch_fc, bands_to_pull[inde], out_csv)
        
        # Iterate over batches and process each one
        for i in range(num_batches):
            process_batch(i * batch_size, i+1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['dist_drain', 'dist_road']
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to D:\tifs\broad_xgb_classification\obs_batches\ca_batches\dist_from_bands\california_shrubs_dist_from_bands_batch_1_env_data.csv
# ...

# %% [markdown]
# ### Shrub per state

# %%
tx_shrubs = ['baccharis_salicina', 'celtis_reticulata', 'chilopsis_linearis', 
             'juniperus_ashei', 'juniperus_monosperma', 'juniperus_pinchotii', 
             'juniperus_virginiana', 'koeberlinia_spinosa', 'larrea_tridentata', 
             'maclura_pomifera', 'morus', 'neltuma_glandulosa', 'neltuma_odorata', 
             'neltuma_velutina', 'parkinsonia_aculeata', 'parkinsonia_texana', 
             'populus_fremontii', 'quercus_havardii', 'salix_exigua', 'salix_gooddingii', 
             'sapindus_drummondii', 'sarcomphalus_obtusifolius', 'strombocarpa_pubescens', 
             'tamarix', 'ulmus_pumila']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
given_state = 'texas'
given_state_abbrev = 'TX'
shrubs_type = []

# Define the column you want to examine (e.g., 'NAME' for state names)
column_name = 'short_epit'
# Aggregate all values from the specified column
values = tex_shrub.aggregate_array(column_name)
# Use distinct() to get unique values
unique_values = values.distinct()
# Get the result as a list
shrubs_type = unique_values.getInfo()
# Print the unique values
print(unique_values_list)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %%
state_data = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{given_state}_shrubs')

for ind in range(len(tx_shrubs)):
    points_datas = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{given_state}/{tx_shrubs[ind]}')
    
    
    # dist drainages...
    nhd_area = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDArea')
    nhd_flowline = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDFlowline')
    nhd = nhd_area.merge(nhd_flowline)
    dist_nhd = nhd.distance(searchRadius=50000)
    #dist_nhd = dist_nhd.clip(ee_items[num]) #change clip area
    dist_nhd = dist_nhd.select(['distance'])
    dist_nhd = dist_nhd.rename('dist_drain')
    dist_nhd = dist_nhd.reproject('EPSG:4326', scale = 1)
    #print(dist_nhd.bandNames().getInfo())
    #Dist roads...
    roads = ee.FeatureCollection('TIGER/2016/Roads')
    dist_roads = roads.distance(searchRadius=50000)
    dist_roads = dist_roads.select(['distance'])
    dist_roads = dist_roads.rename('dist_road')
    dist_roads = dist_roads.reproject('EPSG:4326', scale = 1)
    #print(dist_roads.bandNames().getInfo())
    dist_from_bands = ee.Image([dist_nhd, dist_roads])
    print(dist_from_bands.bandNames().getInfo())

    #bands_to_pull = [polaris_bands, uc_soil_bands, bioclim_bands, dist_from_bands, dem_bands]
    #bands_name = ['polaris_bands', 'uc_soil_bands', 'bioclim_bands', 'dist_from_bands', 'dem_bands']
    bands_to_pull = [dist_from_bands]
    bands_name = ['dist_from_bands']
    
    for inde in range(len(bands_to_pull)):
        # Define the batch size
        batch_size = 250
        
        # Get the total number of features
        num_features = points_datas.size().getInfo()
        
        # Calculate the number of batches
        num_batches = num_features // batch_size
        if num_features % batch_size != 0:
            num_batches += 1
        
        # Define a function to process each batch and export as CSV
        def process_batch(start_index, batch_num):
            # Calculate the end index of the batch
            end_index = start_index + batch_size
            if end_index > num_features:
                end_index = num_features
            
            # Get the features for the current batch
            batch_features = points_datas.toList(batch_size, start_index)
            
            # Create a feature collection for the batch
            batch_fc = ee.FeatureCollection(batch_features)
            
            # then exporting the data as a csv so that can be used in the xgb algorithm
            work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{given_state_abbrev.lower()}_batches/{bands_name[inde]}'
            #work_dir = f'C:/Users/Justin-Laptop/Documents/Research/GEE_LPC/point_data/inat_mesq_obsv/inat_points_env_data/env_batch_csv'
            out_csv = os.path.join(work_dir, f'{given_state}_{tx_shrubs[ind]}_{bands_name[inde]}_batch_{batch_num}_env_data.csv')
            
            #change depending on the bands being pulled
            geemap.extract_values_to_points(batch_fc, bands_to_pull[inde], out_csv)
        
        # Iterate over batches and process each one
        for i in range(num_batches):
            process_batch(i * batch_size, i+1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['dist_drain', 'dist_road']
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to D:\tifs\broad_xgb_classification\obs_batches\tx_batches\dist_from_bands\texas_baccharis_salicina_dist_from_bands_batch_1_env_data.csv
# ...

# %%
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[31.16893065259141, -100.07685257893566], controls=(WidgetControl(options=['position', 'transparent…

# %%
# Load the TIGER dataset
tiger = ee.FeatureCollection("TIGER/2016/States")

# Filter to get the geometry for Texas
texas = tiger.filter(ee.Filter.eq('NAME', 'Texas'))

Map.addLayer(texas, {'color': 'blue', 'weight': 3}, 'Texas')
Map.addLayerControl()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
state_pulling = '48'

Map = geemap.Map()

# Define the state boundary geometry
#data = ee.FeatureCollection('TIGER/2016/States')
#print(data.getInfo())
#texas = data.filter('STATEFP == "Texas"').first().Geometry()

#Map.addLayer(texas, {}, 'Texas')

# Define your polygon boundary
buffer = ee.FeatureCollection('users/jdawsey/assets/20km_buffer')

# Get the extent of the polygon
#extent = buffer.bounds()
# Define the grid parameters (size of the grid cells)
#gridSize = 0.1  # Set the size of grid cells in degrees

# Generate the grid
#grid = buffer.coveringGrid('EPSG:4326')

# Clip the grid to the polygon boundary
#grid_clipped = grid.filterBounds(polygon)

#Map.centerObject(polygon)
Map.addLayer(buffer)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# An attempt at separating into batches any given group of shrubs is larger than 1000

# %%
given_state = texas
given_state_abbrev = TX
state_data = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{given_state}_shrubs')

# Define the column you want to examine (e.g., 'NAME' for state names)
shrub_column = 'short_epit'
# Aggregate all values from the specified column
shrub_values = state_data.aggregate_array(shrub_column)
# Use distinct() to get unique values
shrub_unique_values = shrub_values.distinct()
# Get the result as a list
shrubs_type = shrub_unique_values.getInfo()

for ind in range(len(shrubs_type)):
    points_datas = state_data.filter(f'short_epit == "{shrubs_type[ind]}"')

    # dist drainages...
    nhd_area = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDArea')
    nhd_flowline = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDFlowline')
    nhd = nhd_area.merge(nhd_flowline)
    dist_nhd = nhd.distance(searchRadius=50000)
    #dist_nhd = dist_nhd.clip(ee_items[num]) #change clip area
    dist_nhd = dist_nhd.select(['distance'])
    dist_nhd = dist_nhd.rename('dist_drain')
    dist_nhd = dist_nhd.reproject('EPSG:4326', scale = 1)
    #print(dist_nhd.bandNames().getInfo())
    #Dist roads...
    roads = ee.FeatureCollection('TIGER/2016/Roads')
    dist_roads = roads.distance(searchRadius=50000)
    dist_roads = dist_roads.select(['distance'])
    dist_roads = dist_roads.rename('dist_road')
    dist_roads = dist_roads.reproject('EPSG:4326', scale = 1)
    #print(dist_roads.bandNames().getInfo())
    dist_from_bands = ee.Image([dist_nhd, dist_roads])
    print(dist_from_bands.bandNames().getInfo())

    #bands_to_pull = [polaris_bands, uc_soil_bands, bioclim_bands, dist_from_bands, dem_bands]
    #bands_name = ['polaris_bands', 'uc_soil_bands', 'bioclim_bands', 'dist_from_bands', 'dem_bands']
    bands_to_pull = [dist_from_bands]
    bands_name = ['dist_from_bands']
    
    if points_data.size() > 1000:
        for inde in range(len(bands_to_pull)):
            # Define the batch size
            batch_size = 250
        
            # Get the total number of features
            num_features = points_datas.size().getInfo()
        
            # Calculate the number of batches
            num_batches = num_features // batch_size
            if num_features % batch_size != 0:
                num_batches += 1
        
            # Define a function to process each batch and export as CSV
            def process_batch(start_index, batch_num):
                # Calculate the end index of the batch
                end_index = start_index + batch_size
                if end_index > num_features:
                    end_index = num_features
            
                # Get the features for the current batch
                batch_features = points_datas.toList(batch_size, start_index)
            
                # Create a feature collection for the batch
                batch_fc = ee.FeatureCollection(batch_features)
            
                # then exporting the data as a csv so that can be used in the xgb algorithm
                work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{given_state_abbrev.lower()}_batches/{bands_name[0]}'
                #work_dir = f'C:/Users/Justin-Laptop/Documents/Research/GEE_LPC/point_data/inat_mesq_obsv/inat_points_env_data/env_batch_csv'
                out_csv = os.path.join(work_dir, f'{given_state}_{tx_shrubs[ind]}_{bands_name[0]}_batch_{batch_num}_env_data.csv')
            
                #change depending on the bands being pulled
                geemap.extract_values_to_points(batch_fc, bands_to_pull[0], out_csv)
        
            # Iterate over batches and process each one
            for i in range(num_batches):
                process_batch(i * batch_size, i+1)
    else:
        # then exporting the data as a csv so that can be used in the xgb algorithm
        work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{given_state_abbrev.lower()}_batches/{bands_name[0]}'
        #work_dir = f'C:/Users/Justin-Laptop/Documents/Research/GEE_LPC/point_data/inat_mesq_obsv/inat_points_env_data/env_batch_csv'
        out_csv = os.path.join(work_dir, f'{given_state}_{tx_shrubs[ind]}_{bands_name[0]}_batch_{batch_num}_env_data.csv')
            
        #change depending on the bands being pulled
        geemap.extract_values_to_points(points_data, bands_to_pull[0], out_csv)

# %%
given_state = 'texas'
given_state_abbrev = 'TX'
state_fips = '48'
shrubs_type = []

state_data = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{given_state}_shrubs')


# Define the column you want to examine (e.g., 'NAME' for state names)
shrub_column = 'short_epit'
# Aggregate all values from the specified column
shrub_values = state_data.aggregate_array(shrub_column)
# Use distinct() to get unique values
shrub_unique_values = shrub_values.distinct()
# Get the result as a list
shrubs_type = shrub_unique_values.getInfo()
# Print the unique values
print(shrubs_type)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %% [markdown]
# Grouping into chunks then each chunk by it's county
#
# This works, it just takes a lot of time

# %%
# Function to get state and county info for each point
def addLocationInfo(point):
    state = ee.Feature(states.filterBounds(point.geometry()).first())
    county = ee.Feature(counties.filterBounds(point.geometry()).first())
    state_name = state.get('NAME')
    county_name = county.get('NAME')
    return point.set('state', state_name).set('county', county_name)

# Function to split a collection into chunks
def splitCollection(fc, chunk_size):
    size = fc.size().getInfo()
    indices = list(range(0, size, chunk_size))
    return [fc.toList(chunk_size, i) for i in indices]

# Load the state and county boundary datasets
states = ee.FeatureCollection("TIGER/2018/States")
counties = ee.FeatureCollection("TIGER/2018/Counties")

# Set your given state and abbreviation
given_state = "texas"
given_state_abbrev = "TX"

# Load your points FeatureCollection
points = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{given_state}_shrubs')

# Split points into chunks of 2500 features
chunk_size = 500
points_chunks = splitCollection(points, chunk_size)

batch_num = 0

# Process each chunk separately and export
for i, chunk in enumerate(points_chunks):
    batch_num += 1
    chunk_fc = ee.FeatureCollection(chunk)
    points_with_location_chunk = chunk_fc.map(addLocationInfo)
    
    # Extract environmental data for each county
    county_column = 'county'
    county_values = points_with_location_chunk.aggregate_array(county_column)
    county_unique = county_values.distinct()
    county_names = county_unique.getInfo()
    
    for county_name in county_names:
        points_to_download = points_with_location_chunk.filter(ee.Filter.eq(county_column, county_name))
    
        nhd_area = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDArea')
        nhd_flowline = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDFlowline')
        nhd = nhd_area.merge(nhd_flowline)
        dist_nhd = nhd.distance(searchRadius=50000)
        dist_nhd = dist_nhd.select(['distance'])
        dist_nhd = dist_nhd.rename('dist_drain')
        dist_nhd = dist_nhd.reproject('EPSG:4326', scale = 1)
        
        roads = ee.FeatureCollection('TIGER/2016/Roads')
        dist_roads = roads.distance(searchRadius=50000)
        dist_roads = dist_roads.select(['distance'])
        dist_roads = dist_roads.rename('dist_road')
        dist_roads = dist_roads.reproject('EPSG:4326', scale = 1)
        
        dist_from_bands = ee.Image([dist_nhd, dist_roads])
        
        bands_to_pull = [dist_from_bands]
        bands_name = 'dist_from_bands'

        work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{given_state_abbrev.lower()}_batches/{bands_name}'
        out_csv = os.path.join(work_dir, f'{given_state}_{county_name}_{bands_name}_batch_{batch_num}_env_data.csv')
        
        geemap.extract_values_to_points(points_to_download, bands_to_pull, out_csv)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to D:\tifs\broad_xgb_classification\obs_batches\tx_batches\dist_from_bands\texas_Kimble_dist_from_bands_batch_2_env_data.csv
# Generating URL ...
# ...
# Please wait ...
# ...

# %% [markdown]
# Grouping features by county

# %%
# Function to get state and county info for each point
def addLocationInfo(point):
    state = ee.Feature(states.filterBounds(point.geometry()).first())
    county = ee.Feature(counties.filterBounds(point.geometry()).first())
    state_name = state.get('NAME')
    county_name = county.get('NAME')
    return point.set('state', state_name).set('county', county_name)

# Function to split a collection into chunks
def splitCollection(fc, chunk_size):
    size = fc.size().getInfo()
    indices = list(range(0, size, chunk_size))
    return [fc.toList(chunk_size, i) for i in indices]

# Load the state and county boundary datasets
states = ee.FeatureCollection("TIGER/2018/States")
counties = ee.FeatureCollection("TIGER/2018/Counties")

# Set your given state and abbreviation
given_state = "texas"
given_state_abbrev = "TX"

# Load your points FeatureCollection
points = ee.FeatureCollection(f'projects/ee-jdawsey/assets/states_shrubs/{given_state}_shrubs')
points_with_location = points.map(addLocationInfo)

# Group shrubs by county
groups = points_with_location.group('county')

batch_num = 0

# Process each county group separately and export
for group in groups:
    county_name = ee.Feature(group).get('group').getInfo()  # Get county name from the group
    points_in_county = ee.FeatureCollection(group)  # Get all points in the county
    
    # Check if the county contains more than 2000 features
    num_features = points_in_county.size().getInfo()
    
    if num_features <= 2000:
        # Extract environmental data for the county
        nhd_area = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDArea')
        nhd_flowline = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDFlowline')
        nhd = nhd_area.merge(nhd_flowline)
        dist_nhd = nhd.distance(searchRadius=50000)
        dist_nhd = dist_nhd.select(['distance'])
        dist_nhd = dist_nhd.rename('dist_drain')
        dist_nhd = dist_nhd.reproject('EPSG:4326', scale = 1)
        
        roads = ee.FeatureCollection('TIGER/2016/Roads')
        dist_roads = roads.distance(searchRadius=50000)
        dist_roads = dist_roads.select(['distance'])
        dist_roads = dist_roads.rename('dist_road')
        dist_roads = dist_roads.reproject('EPSG:4326', scale = 1)
        
        dist_from_bands = ee.Image([dist_nhd, dist_roads])
        
        bands_to_pull = [dist_from_bands]
        bands_name = 'dist_from_bands'

        work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{given_state_abbrev.lower()}_batches/{bands_name}'
        out_csv = os.path.join(work_dir, f'{given_state}_{county_name}_{bands_name}_batch_{batch_num}_env_data.csv')
        
        geemap.extract_values_to_points(points_in_county, bands_to_pull, out_csv)
        
    else:
        # Split the county into smaller chunks and export each chunk separately
        chunk_size = 2000
        points_chunks = splitCollection(points_in_county, chunk_size)
        
        for i, chunk in enumerate(points_chunks):
            batch_num += 1
            chunk_fc = ee.FeatureCollection(chunk)
            
            # Extract environmental data for the chunk
            nhd_area = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDArea')
            nhd_flowline = ee.FeatureCollection(f'projects/sat-io/open-datasets/NHD/NHD_{given_state_abbrev}/NHDFlowline')
            nhd = nhd_area.merge(nhd_flowline)
            dist_nhd = nhd.distance(searchRadius=50000)
            dist_nhd = dist_nhd.select(['distance'])
            dist_nhd = dist_nhd.rename('dist_drain')
            dist_nhd = dist_nhd.reproject('EPSG:4326', scale = 1)
            
            roads = ee.FeatureCollection('TIGER/2016/Roads')
            dist_roads = roads.distance(searchRadius=50000)
            dist_roads = dist_roads.select(['distance'])
            dist_roads = dist_roads.rename('dist_road')
            dist_roads = dist_roads.reproject('EPSG:4326', scale = 1)
            
            dist_from_bands = ee.Image([dist_nhd, dist_roads])
            
            bands_to_pull = [dist_from_bands]
            bands_name = 'dist_from_bands'
    
            work_dir = f'D:/tifs/broad_xgb_classification/obs_batches/{given_state_abbrev.lower()}_batches/{bands_name}'
            out_csv = os.path.join(work_dir, f'{given_state}_{county_name}_{bands_name}_batch_{batch_num}_chunk_{i+1}_env_data.csv')
            
            geemap.extract_values_to_points(chunk_fc, bands_to_pull, out_csv)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 28
# ...

# %% [markdown]
# Attempting to add points to a grid instead of by county
