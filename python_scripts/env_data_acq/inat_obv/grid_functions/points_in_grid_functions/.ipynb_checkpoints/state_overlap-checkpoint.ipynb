# %%
import os
import geopandas as gpd
import pandas as pd
#from shapely.geometry import box, Point
#import numpy as np
#import pandas as pd
import geemap
#import folium
#import fiona
#import sys

# %%
folder_path = 'D:/tifs/broad_xgb_classification'
# Load the shapefiles
points_gdf = gpd.read_file(f'{folder_path}/state_shrub_shps/az_nm_shrubs/az_nm_shrubs.shp')
states_gdf = gpd.read_file(f'{folder_path}/states_shp/US_States.shp')

# Ensure both GeoDataFrames have the same CRS
if points_gdf.crs != states_gdf.crs:
    states_gdf = states_gdf.to_crs(points_gdf.crs)

# Perform the spatial join
points_with_states = gpd.sjoin(points_gdf, states_gdf, how='left', predicate='within')

# Display the resulting GeoDataFrame
points_with_states.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        latitude     longitude          scientific          short_epit  \
# 0  1.655103e+06 -1.359087e+06  Baccharis salicina  Baccharis salicina
# 1  1.571319e+06 -1.429195e+06  Baccharis salicina  Baccharis salicina
# 2  1.031860e+06 -1.347166e+06  Baccharis salicina  Baccharis salicina
# 3  1.402020e+06 -1.639161e+06  Baccharis salicina  Baccharis salicina
# 4  1.040333e+06 -1.331943e+06  Baccharis salicina  Baccharis salicina
#
#        genus                          geometry  index_right  \
# 0  baccharis  POINT (-1359086.837 1655103.445)           55
# 1  baccharis  POINT (-1429194.775 1571318.785)           55
# 2  baccharis  POINT (-1347166.260 1031860.318)           55
# 3  baccharis  POINT (-1639160.852 1402019.566)           55
# 4  baccharis  POINT (-1331942.931 1040333.440)           55
#
#                              PERMANENT_ SOURCE_FEA  \
# 0  b2f83cf3-e01b-4cf6-afbb-b7f75a4cb4ac         04
# 1  b2f83cf3-e01b-4cf6-afbb-b7f75a4cb4ac         04
# 2  b2f83cf3-e01b-4cf6-afbb-b7f75a4cb4ac         04
# 3  b2f83cf3-e01b-4cf6-afbb-b7f75a4cb4ac         04
# 4  b2f83cf3-e01b-4cf6-afbb-b7f75a4cb4ac         04
#
#                              SOURCE_DAT  ...  FCODE STATE_FIPS  STATE_NAME  \
# 0  27cbc96d-9c13-4510-b0e4-03824b09225a  ...  61100         04     Arizona
# 1  27cbc96d-9c13-4510-b0e4-03824b09225a  ...  61100         04     Arizona
# 2  27cbc96d-9c13-4510-b0e4-03824b09225a  ...  61100         04     Arizona
# 3  27cbc96d-9c13-4510-b0e4-03824b09225a  ...  61100         04     Arizona
# 4  27cbc96d-9c13-4510-b0e4-03824b09225a  ...  61100         04     Arizona
#
#   POPULATION       AREASQKM  GNIS_ID         GNIS_NAME  \
# 0    6392017  295219.871116  1779777  State of Arizona
# 1    6392017  295219.871116  1779777  State of Arizona
# 2    6392017  295219.871116  1779777  State of Arizona
# 3    6392017  295219.871116  1779777  State of Arizona
# 4    6392017  295219.871116  1779777  State of Arizona
#
#                                  GLOBALID  SHAPE_Leng  SHAPE_Area
# 0  {3B978AF7-94DA-46E7-89A8-3C439F7D4AEC}   23.915972   28.917764
# 1  {3B978AF7-94DA-46E7-89A8-3C439F7D4AEC}   23.915972   28.917764
# 2  {3B978AF7-94DA-46E7-89A8-3C439F7D4AEC}   23.915972   28.917764
# 3  {3B978AF7-94DA-46E7-89A8-3C439F7D4AEC}   23.915972   28.917764
# 4  {3B978AF7-94DA-46E7-89A8-3C439F7D4AEC}   23.915972   28.917764
#
# [5 rows x 25 columns]

# %%
extracted_col = points_with_states["STATE_NAME"]
points_gdf['state'] = points_with_states["STATE_NAME"]
points_gdf.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#        latitude     longitude          scientific          short_epit  \
# 0  1.655103e+06 -1.359087e+06  Baccharis salicina  Baccharis salicina
# 1  1.571319e+06 -1.429195e+06  Baccharis salicina  Baccharis salicina
# 2  1.031860e+06 -1.347166e+06  Baccharis salicina  Baccharis salicina
# 3  1.402020e+06 -1.639161e+06  Baccharis salicina  Baccharis salicina
# 4  1.040333e+06 -1.331943e+06  Baccharis salicina  Baccharis salicina
#
#        genus                          geometry    state
# 0  baccharis  POINT (-1359086.837 1655103.445)  Arizona
# 1  baccharis  POINT (-1429194.775 1571318.785)  Arizona
# 2  baccharis  POINT (-1347166.260 1031860.318)  Arizona
# 3  baccharis  POINT (-1639160.852 1402019.566)  Arizona
# 4  baccharis  POINT (-1331942.931 1040333.440)  Arizona

# %%
#file_path = os.path.join(output_folder, f'cell_{idx}.shp')
file_path = f'{folder_path}/state_shrub_shps/az_nm_shrubs/az_nm_shrubs_w_states.shp'
points_gdf.to_file(file_path, driver='ESRI Shapefile')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
checking_gdf = gpd.read_file(f'{folder_path}/state_shrub_shps/az_nm_shrubs/az_nm_shrubs_w_states.shp')
az_nm_shrubs = gpd.read_file(f'{folder_path}/state_shrub_shps/az_nm_shrubs/az_nm_shrubs.shp')
print(len(checking_gdf.axes[0]))
print(len(az_nm_shrubs.axes[0]))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 57155
# 57155
