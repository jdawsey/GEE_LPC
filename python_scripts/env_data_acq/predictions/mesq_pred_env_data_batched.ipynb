# %% [markdown]
# # Necessary to check that the functions are all still relevant

# %%
import ee
import geemap
import json
import os
import sys
from geemap import geojson_to_ee
from ipyleaflet import GeoJSON
sys.path.insert(1, 'D:/!!Research/rgee_test/GEE_LPC/python_scripts')
from my_gee_functions import file_address_func
from my_gee_functions import ee_list_func
from my_gee_functions import stdrd_func
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Authenticate if needed
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=dateOBC3u7vkzbR0o_M4vcq8E08rzndZn_dRjKQYma0&tc=qFf0qbWkrSp-z79lW6CeIMHSgVUjfilnNV9-Xhlb6is&cc=0pt3mriZ_suSzd3PRSMeXrMKzi512n_xtbZEL8Oth50>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=dateOBC3u7vkzbR0o_M4vcq8E08rzndZn_dRjKQYma0&tc=qFf0qbWkrSp-z79lW6CeIMHSgVUjfilnNV9-Xhlb6is&cc=0pt3mriZ_suSzd3PRSMeXrMKzi512n_xtbZEL8Oth50</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AdLIrYd6wdqWAmXHOa7ibEo-wpyzZEdiryOSdc25XYhOtwvxtNbiGHeTUX8
# Successfully saved authorization token.

# %%
#Initializing the ee project

ee.Initialize(project = 'ee-jdawsey')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Actually pulling the data
#
# For polaris: Can choose from 0_5, 5_15, 15_30, 30_60, 60_100, 100_200

# %%
bd_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_0_5')
bd_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_5_15')
bd_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_15_30')
bd_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_30_60')
bd_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_60_100')
bd_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/bd_mean/bd_100_200')

bd_env_bands = ee.Image([bd_0_5, bd_5_15, bd_15_30, bd_30_60, bd_60_100, bd_100_200])
bd_env_bands = bd_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
bd_env_bands = bd_env_bands.rename('bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200')

print(bd_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200']

# %%
clay_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_0_5')
clay_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_5_15')
clay_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_15_30')
clay_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_30_60')
clay_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_60_100')
clay_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/clay_mean/clay_100_200')

clay_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
clay_env_bands = clay_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
clay_env_bands = clay_env_bands.rename('clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200')

print(clay_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200']

# %%
ksat_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_0_5')
ksat_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_5_15')
ksat_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_15_30')
ksat_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_30_60')
ksat_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_60_100')
ksat_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/ksat_mean/ksat_100_200')

ksat_env_bands = ee.Image([ksat_0_5, ksat_5_15, ksat_15_30, ksat_30_60, ksat_60_100, ksat_100_200])
ksat_env_bands = ksat_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
ksat_env_bands = ksat_env_bands.rename('ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200')

print(ksat_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200']

# %%
om_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_0_5')
om_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_5_15')
om_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_15_30')
om_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_30_60')
om_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_60_100')
om_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/om_mean/om_100_200')

om_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
om_env_bands = om_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
om_env_bands = om_env_bands.rename('om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200')

print(om_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200']

# %%
ph_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_0_5')
ph_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_5_15')
ph_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_15_30')
ph_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_30_60')
ph_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_60_100')
ph_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/ph_mean/ph_100_200')

ph_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
ph_env_bands = ph_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
ph_env_bands = ph_env_bands.rename('ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200')

print(ph_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200']

# %%
sand_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_0_5')
sand_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_5_15')
sand_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_15_30')
sand_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_30_60')
sand_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_60_100')
sand_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/sand_mean/sand_100_200')

sand_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
sand_env_bands = sand_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
sand_env_bands = sand_env_bands.rename('sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200')

print(sand_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200']

# %%
silt_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_0_5')
silt_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_5_15')
silt_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_15_30')
silt_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_30_60')
silt_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_60_100')
silt_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/silt_mean/silt_100_200')

silt_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
silt_env_bands = silt_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
silt_env_bands = silt_env_bands.rename('silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200')

print(silt_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200']

# %%
theta_r_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_0_5')
theta_r_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_5_15')
theta_r_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_15_30')
theta_r_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_30_60')
theta_r_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_60_100')
theta_r_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/theta_r_mean/theta_r_100_200')

theta_r_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
theta_r_env_bands = theta_r_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
theta_r_env_bands = theta_r_env_bands.rename('theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200')

print(theta_r_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200']

# %%
theta_s_0_5 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_0_5')
theta_s_5_15 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_5_15')
theta_s_15_30 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_15_30')
theta_s_30_60 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_30_60')
theta_s_60_100 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_60_100')
theta_s_100_200 = ee.Image('projects/sat-io/open-datasets/polaris/theta_s_mean/theta_s_100_200')

theta_s_env_bands = ee.Image([clay_0_5, clay_5_15, clay_15_30, clay_30_60, clay_60_100, clay_100_200])
theta_s_env_bands = theta_s_env_bands.select(['b1', 'b1_1', 'b1_2', 'b1_3', 'b1_4', 'b1_5'])
theta_s_env_bands = theta_s_env_bands.rename('theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200')

print(theta_s_env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200']

# %%
env_bands_temp = ee.Image([bd_env_bands, 
                           clay_env_bands, 
                           ksat_env_bands, 
                           om_env_bands, 
                           ph_env_bands, 
                           sand_env_bands,
                           silt_env_bands,
                           theta_r_env_bands,
                           theta_s_env_bands])
print(env_bands_temp.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200', 'clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200', 'ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200', 'om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200', 'ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200', 'sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200', 'silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200', 'theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200', 'theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200']

# %%
caco3 = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/caco3')
caco3 = caco3.select(['b1'])
caco3 = caco3.resample('bicubic').reproject('EPSG:4326', scale = 30)
caco3 = caco3.rename('caco3')
#print(caco3.bandNames().getInfo())

cec = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/cec')
cec = cec.select(['b1'])
cec = cec.resample('bicubic').reproject('EPSG:4326', scale = 30)
cec = cec.rename('cec')

ec = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/ec')
ec = ec.select(['b1'])
ec = ec.resample('bicubic').reproject('EPSG:4326', scale = 30)
ec = ec.rename('ec')

sar = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/chemical/sar')
sar = sar.select(['b1'])
sar = sar.resample('bicubic').reproject('EPSG:4326', scale = 30)
sar = sar.rename('sar')

kw_025 = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/kw_025')
kw_025 = kw_025.select(['b1'])
kw_025 = kw_025.resample('bicubic').reproject('EPSG:4326', scale = 30)
kw_025 = kw_025.rename('kw_025')

#lcc_i = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/lcc_i')
#lcc_i = lcc_i.select(['b1'])
#lcc_i = lcc_i.resample('bicubic').reproject('EPSG:4326', scale = 30)
#lcc_i = lcc_i.rename('lcc_i')

#lcc_ni = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/lcc_ni')
#lcc_ni = lcc_ni.select(['b1'])
#lcc_ni = lcc_ni.resample('bicubic').reproject('EPSG:4326', scale = 30)
#lcc_ni = lcc_ni.rename('lcc_ni')

resdept = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/resdept')
resdept = resdept.select(['b1'])
resdept = resdept.resample('bicubic').reproject('EPSG:4326', scale = 30)
resdept = resdept.rename('resdept')

soil_depth = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/soil_depth')
soil_depth = soil_depth.select(['b1'])
soil_depth = soil_depth.resample('bicubic').reproject('EPSG:4326', scale = 30)
soil_depth = soil_depth.rename('soil_depth')

#soil_temp_regime = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/soil_temp_regime')
#soil_temp_regime = soil_temp_regime.select(['b1'])
#soil_temp_regime = soil_temp_regime.resample('bicubic').reproject('EPSG:4326', scale = 30)
#soil_temp_regime = soil_temp_regime.rename('soil_temp_regime')

wind_erodibility_index = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/land_use/wind_erodibility_index')
wind_erodibility_index = wind_erodibility_index.select(['b1'])
wind_erodibility_index = wind_erodibility_index.resample('bicubic').reproject('EPSG:4326', scale = 30)
wind_erodibility_index = wind_erodibility_index.rename('wind_erodibility_index')

rf_025 = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/physical/rf_025')
rf_025 = rf_025.select(['b1'])
rf_025 = rf_025.resample('bicubic').reproject('EPSG:4326', scale = 30)
rf_025 = rf_025.rename('rf_025')

water_storage = ee.Image('projects/earthengine-legacy/assets/projects/sat-io/open-datasets/CSRL_soil_properties/physical/water_storage')
water_storage = water_storage.select(['b1'])
water_storage = water_storage.resample('bicubic').reproject('EPSG:4326', scale = 30)
water_storage = water_storage.rename('water_storage')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_bands_temp2 = ee.Image([env_bands_temp, 
                           caco3, 
                           cec, 
                           ec, 
                           sar, 
                           kw_025,
                           #lcc_i,
                           #lcc_ni,
                           resdept,
                           soil_depth,
                           #soil_temp_regime,
                           wind_erodibility_index,
                           rf_025,
                           water_storage])
print(env_bands_temp2.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200', 'clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200', 'ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200', 'om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200', 'ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200', 'sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200', 'silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200', 'theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200', 'theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200', 'caco3', 'cec', 'ec', 'sar', 'kw_025', 'resdept', 'soil_depth', 'wind_erodibility_index', 'rf_025', 'water_storage']

# %%
bioclim = ee.Image('WORLDCLIM/V1/BIO')
ann_rain = bioclim.select(['bio12'])
#bioclim_proj = ann_rain.projection().getInfo()
#bioclim_crs = bioclim_proj['crs']
ann_rain = ann_rain.resample('bicubic').reproject('EPSG:4326', scale = 30)

temp_range = bioclim.select(['bio07'])
temp_range = temp_range.resample('bicubic').reproject('EPSG:4326', scale = 30)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
env_bands_temp3 = ee.Image([env_bands_temp2, ann_rain, temp_range])
print(env_bands_temp3.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200', 'clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200', 'ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200', 'om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200', 'ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200', 'sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200', 'silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200', 'theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200', 'theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200', 'caco3', 'cec', 'ec', 'sar', 'kw_025', 'resdept', 'soil_depth', 'wind_erodibility_index', 'rf_025', 'water_storage', 'bio12', 'bio07']

# %%
nhd_area_nm = ee.FeatureCollection("projects/sat-io/open-datasets/NHD/NHD_NM/NHDArea")
nhd_flowline_nm = ee.FeatureCollection("projects/sat-io/open-datasets/NHD/NHD_NM/NHDFlowline")
nhd_nm = nhd_area_nm.merge(nhd_flowline_nm)
nhd_area_tx = ee.FeatureCollection("projects/sat-io/open-datasets/NHD/NHD_TX/NHDArea")
nhd_flowline_tx = ee.FeatureCollection("projects/sat-io/open-datasets/NHD/NHD_TX/NHDFlowline")
nhd_tx = nhd_area_tx.merge(nhd_flowline_tx)

nhd = nhd_nm.merge(nhd_tx)

dist_nhd = nhd.distance(searchRadius=50000, maxError=50)
#dist_nhd = dist_nhd.clip(ee_items[num]) #change clip area
dist_nhd = dist_nhd.select(['distance'])
dist_nhd = dist_nhd.rename('dist_drain')
print(dist_nhd.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['dist_drain']

# %%
#Dist roads...

roads = ee.FeatureCollection('TIGER/2016/Roads')
dist_roads = roads.distance(searchRadius=50000, maxError=50)
dist_roads = dist_roads.select(['distance'])
dist_roads = dist_roads.rename('dist_road')
print(dist_roads.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['dist_road']

# %%
env_bands = ee.Image([env_bands_temp3, dist_nhd, dist_roads])
print(env_bands.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200', 'clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200', 'ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200', 'om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200', 'ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200', 'sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200', 'silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200', 'theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200', 'theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200', 'caco3', 'cec', 'ec', 'sar', 'kw_025', 'resdept', 'soil_depth', 'wind_erodibility_index', 'rf_025', 'water_storage', 'bio12', 'bio07', 'dist_drain', 'dist_road']

# %%
#buffer = ee.FeatureCollection('users/jdawsey/assets/20km_buffer')
#std_env_clip = stdrd_func(env_bands, buffer)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
points_data = ee.FeatureCollection('projects/ee-jdawsey/assets/poly31_mesq_pred_points')

#Map.addLayer(points_data, {}, 'points_data')
#Map.addLayer(buffer, {}, 'buffer')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# polygon number being worked with
poly_num = 31

# Define the batch size
batch_size = 2500

# Get the total number of features
num_features = points_data.size().getInfo()

# Calculate the number of batches
num_batches = num_features // batch_size
if num_features % batch_size != 0:
    num_batches += 1

# Define a function to process each batch and export as CSV
def process_batch(start_index, batch_num):
    # Calculate the end index of the batch
    end_index = start_index + batch_size
    if end_index > num_features:
        end_index = num_features
    
    # Get the features for the current batch
    batch_features = points_data.toList(batch_size, start_index)
    
    # Create a feature collection for the batch
    batch_fc = ee.FeatureCollection(batch_features)
    
    # then exporting the data as a csv so that can be used in the xgb algorithm
    work_dir = f'D:/!!Research/rgee_test/GEE_LPC/point_data/mesq_location_predictions/poly{poly_num}/env_batch_csv'
    out_csv = os.path.join(work_dir, f'poly{poly_num}_batch_{batch_num}_env_data.csv')
    geemap.extract_values_to_points(batch_fc, env_bands, out_csv)

# Iterate over batches and process each one
for i in range(num_batches):
    process_batch(i * batch_size, i+1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/071bc36bba2e75fa4c24af3a70e9ec41-f66648a3a52ad9cb9f5cc06a5aa74292:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_1_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/46abf3ac785b6a912bc76463a0eb8874-d8a0b57f44e6c5214c2c60edf465bbb8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_2_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4fb98400e2588ce67b7cdff63e61c583-35c9442fa8734af1c096f7db954d259f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_3_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/91874a7289960d27686418e573146de9-61aa127eec3e7b6b96b0b3986882a02c:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_4_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/096a30c013f7776795c9201ddec89b3a-5422c4dae7d9ea42c096a14691d19211:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_5_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/9774b4782912c5677e4d6a7d40b03ee4-2f5299766fe8597e6464dfb9e30dc83d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_6_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/597f6dfe67d2690a70ce1c097713e8b0-8cdcc6da8fc1afbbd3de783be3d3581e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_7_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/406d64a5bd04c52f9236cdebbaff77ab-c9ddb77a23bf3802a815f79866ca127f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_8_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/f858795d97c57abbeced570d754ecebd-b3176bae570a9536563cfff820edf17e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_9_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/deb053fe578ad6a65f05d843d5f0d005-0446bdfd6dbbd7215af50182da4c4550:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_10_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/b16d97c2d8d87f6d6f64e699b6e7b0fd-a793c81451366fde80a0743c1d8a80d6:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_11_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/9e75ed66cbcd69a97fe188047b8982a1-025cc4d870f525e8c56e45f4d6f1da8a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_12_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/0f297ffdbe221d8c83c292bfe507cb4f-a458bb2bdb26a3f8ce942100e47d06bf:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_13_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/427c3c0ef20d6857a19d3b62eb5a1bd5-15b583dd054bb6f4640fcc194023d02a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_14_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/9c1e9c36ca41dac539fba010768eb1b6-cd315f0d6530979eb5c79c8b5e36285e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_15_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/5f5b1a3c6433ee56d827a8839819cbb1-4e7ebae3f238c6e85d8b7b895975f9e0:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_16_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/a87d69989dff51b787fa55e93f398df3-dcca76bd6bf2e998dd585db5ca3296a8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_17_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/50be93991f43a1b82342e4f8b7380de6-730b78732c946b0027217be74a125fe5:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_18_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/e9aa33ab3448fe607398b517bb5cb5f4-c1e525c80347e41642f47fd524eae187:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_19_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/f367894322c5f5526cb31cdcdf8b530e-ac6f5b7f0a9eb7fa685716c1a82f928a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_20_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/6df4717e5f141d104cb1db4d254c606b-37aa52e7cc0958e82fb00babc3f743ee:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_21_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/b78e9b41b66c3d7cbeb3b0b36c0157f0-64d89d0726cac17f174f345f98f1e980:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_22_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2f7cc20d6686497dfc18df41c3757063-b4694fb08889bc3a55abed31bd56f59a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_23_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/eb5d97fe68170d86b17d84ba373a35c6-f2c5be3fb68550e55edcabe4c9647dd2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_24_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/bf284803990d62f4c3c8ad77cddbc47a-07b711dc46c9edf9055814fdd38a834b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_25_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/ab847b00f552daccfce40a5948f8b48a-8dbd71fca72459b23ee3d08de1640a52:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_26_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/fa8ceaa75120ab55987030edc6de25dc-88c7cdfd18151ea366af56f8f746e7a4:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_27_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2c481527b23c2acf941e59d0124dca7c-4646bcad4ee26e340bfdc52ddd5158a6:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_28_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/a6952da274b935fcb98982c813f211d9-a57adb75f4167c79902af093bcb6a9f7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_29_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4ea2e377f02617ee61803402643dbf1b-f5b6fe71df0326aea31af264199a94b1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_30_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/99a4761faa117582dbe17056c438953f-4232ca8609844418bf4c1195d6d26d91:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_31_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/8e7de81a65117464e6802b1c93f2168a-9414bc8a67068424d10daf09f04bea31:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_32_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/7c125d5a5e5e2d26fc08a34ecd72d35f-b96cff37c5971500cc34f841f6dfc2ad:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_33_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/6de71445831751915651a26476deb92e-9fc07831787b4a32f6c0446c69b4608b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_34_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/24cdb1aa69b29687e3c370fbe8c09d26-d7be8daad4c0c539e2c7417595203f94:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_35_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/d178882d6b8f2ef8a12170b5b09183d1-db034ab448446e7b195164ff12100519:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_36_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/f6bfa9a16cf37dfe36569bec2d0b73aa-6a38d10ca5861f3f07ae59d9fef5ef3a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_37_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/55d14b3a2ad60222c95f8a1d08f0cc61-65bab0051a576488b233d6bb94a36ed1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_38_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/d759d3d977b7c911cef00671da2f278e-b735c418384bd0326d1c83772016f4f9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_39_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/caf9e3b8f1f71110194810c7d2093eda-beb373af7303460030f2a3a4f0e07bda:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_40_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2e8f6015e7f08dd2c5c71430a5fba338-0352f24f68ff066228515562f9079618:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_41_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/701441807a54ce520df4b011917488f0-d2221f85a78f42f06063430897a4a2f8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_42_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/8074df70bb1e734d18f4dadf81631df9-646f8c9294d53c88f58ec3c48e6884d1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_43_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/31af956d9292053edaf9b49e9a43aee0-d80ed46ccf26e6433701bf11c9a8c562:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_44_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/180fc565cdfa4587405c87087b11ccd2-618c874a0f76165739026d752793afca:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_45_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/5a4c1e6317c763e1a2662bd7bfbde602-7ad6b9efcd355b0dc8de62c7754b9452:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_46_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/3c9f2f8a746e55cc0f7046a965d5368f-6b3ad4518f1e85970d9732f7b086ba81:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_47_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/3dac8bf0ecd7670a65c0d6f6f77a8efe-180b35c5775b10f26dd20b7b0e6acc6b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_48_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/bd95ee8192e82253aa5ae0d24813267a-1a4b91590f5901fe40e775e7d7e40f00:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_49_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/5dc8edf95d63d967a5b3b49e5bc32f12-fdc7b1ac4f08f627a3735bb130af6e2d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_50_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/e25cf7f2115a4acd719fb88c0c71639d-2d316e2c3288e988f1c589f334cec8f7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_51_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/0cbb7d15ff2c2f7ab826013d3e6f913c-87bf945188ec713b4516eac5ead3b571:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_52_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/9ea69e060847a932720a7abfe71e9c3e-bade27c931296c3b15dbf173b3d988d5:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_53_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/d5fd70b0e47c0e1aa8dc0f83896c20ab-b822357d1ad4c8bf4ddeb250b07895ba:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_54_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/6572950c88ec99ceec74b99fdd5c146b-21c7ecd750e566a33b45b2ec7647b3b1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_55_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/1fdffd2ace57eedb924acb3b307bf22d-6cb8923e53ccae7730cc85f29c7e2635:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_56_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/5db448aada001ade6bc8969af21f848a-275e0819bf09cf52e930d9c2b66004da:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_57_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/84221853ebda953f0f65f03576b7925e-aae77fcc972d2f3b4989597f073a5fad:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_58_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/302b63729bb24e4659dd46fbc2fc633e-24c40c32f4d170ad4f38c57c86555ca9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_59_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/95052b12eb8c51e2bb5d57ab858f6930-71a22543b461d57144737a8c134ad3e8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_60_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/20a7d0d33ed1f585e2977db7e8eee01d-9eac7913932d751982ca8ec73ee10ce8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_61_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/f7341992a4cca0ae578cd0d5dd8d46c5-23599c568687e528ed017a48016ffe8f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_62_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/695ec5a21a1d11f1c0b83a0413f81f98-5de09b1260208b46daa1e9228806190d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_63_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/1fcd48b147fc70bb6e80deef557ad314-163f4d615d99c8823f1afb780423aab1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_64_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/70ae81bc40408d459e4c9397971ee2ad-b6a2f8f43fe120368080ff3ae7a1150d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_65_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/c7d9b312c6c29140118fea29c0fbe8b4-ec0b4f0a06c0cefd1021c5d4464254b4:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_66_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/f7877e354e6bad628e63db5eaac00fc7-ddf64742458651092b1226de9321eb95:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_67_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/dbe6aef04ab654f11894fb9aae543a7c-f732de5dd6d5b87465b54f377fb0e545:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_68_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/1da01a328dc8efa914c12ddb8458596a-94d363139f28e2dc61f04d484a5863e1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_69_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/cc51cff051be0bb09e96c9a5148268d3-31133322064b3215db89ac1f447434eb:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_70_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/efe1a3cec2fb9cc4c9be11bbee90dff7-1781b3726a2d3ac0b1ca981a932dbe68:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_71_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/89e132c1566108a98beb392861159b9a-f1731328a82aecc702f33a1699e9ad4d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_72_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/67ae046fce2fcf5b1a8183e2577d00a9-671bde3236c4a725c6e4f923d63af01b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_73_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4f26c71c4563d4500c0cbd6ac612e68f-2f7e85c97fe21ee3b531730f26783324:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_74_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/8dcac73edf27537d374e79f42b517357-4c029e9fa19dd682604c04c96f2b2661:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_75_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4665eb5ea404d9b94d5c92fbf3c0387c-9dd9ca718b767633d88b27f9ceee0b9e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_76_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/194a258ea7ea38a6a54735f0d8cd05a6-d67c66f50e3b00c7113e1546bce41af0:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_77_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/9a60bbfa781318c0f752e7738085abfb-4b558692b0f72fea3abefec8ab6394b8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_78_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/ac7f3716acb00c0671e4fabf3f6d54fb-10b9b3570c68b1d27585b049af699c56:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_79_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/75400dbef2f87036ffd5a83c6b9b29f3-09f9888d5ec10895add92b9b7f8d5ce0:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_80_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/e4fe0f1fcf1789203187754dfd2202e2-c71557e5c7d066016d25bbbc5a3ed670:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_81_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/cb1f9f941da6f257c347d243c8ede007-fc881d809f368a40ca1335606f00e9fb:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_82_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2a3b8f419f7464513dcd0c5cdfdf48fa-957f7a74a859c0f6ee285630b4cbc126:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_83_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/9b05f8a721fa11d0c2719637b8e51acf-b2f8429379a42a5b80ee281b94dc2491:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_84_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/fbda27fc7944c5ad8240003842b7849b-9a2d46aa500e24857926a1a1880db07a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_85_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/bca80ba04f06d69bfd4966bef551fd2b-8632ff400316c71b78f43e8f85d8aa86:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_86_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/cad24fbafa1fab8c5bb692ec96ec43f0-c9cb998f0c93f6a966b71514b0a8b3a9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_87_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/70c2986fb368de01c4bcb576348762a1-beeec9a18d6a77d04b4ff2b3c9a3c0e8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_88_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/117fb17dfa281f4626f548fee7e7cf3e-d20f452549fc023d6dc7c683f9895f9c:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_89_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/8b728696c23c38de71d93f5fe00bcee0-f8b165301e7921f3caad6f3ccfaf887a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_90_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/e13063f41f2db928b5b550ee1f527417-9558615a024c77a0958d413d38590c68:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_91_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/1dfbf1b0cc990967cd5cd4f481ddb4db-380ae58eebcef0cacada0eddd3fac966:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_92_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/374689db70badfe678edd5fe64068799-da56e97e0bb77cee29313581288f8ae4:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_93_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/d42ae54354fdb515491ca1ff83ce8ec5-5053115812cf763fd639b4b9c4ec0b46:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_94_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2b402a3189dfde232b6f19fb9fffcdc4-44de936cf045d07c56e7316972cf9a58:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_95_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/a6256bd5945be5a017b28ffa425545ba-5099ace6e63745494e1a8bf127c7e909:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_96_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/c2f0b6b9d9698592f6f9696c523941aa-904ab9d05aa92f5da33869a3bfa46986:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_97_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/bc855f49315630fd0d80d7f376cb8261-c32c172056a65f92ca958149e4138534:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_98_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/204a38973f91c8a5bf8d6750258d54f4-7cfffcc7422b438f1d2b3f2e36aa233c:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_99_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/503e37a6d1774be7246e323d7306d4e4-b4dab39e80149575758b64c256ed7d71:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_100_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/8e0eb3f646a44c38bd5ca9e758dfe946-105273a1869ae2472ffd500e9d602a01:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_101_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/b1a786965161c39c85ae51a125965c66-0572c11ba5a8883d0a5d0b9f3a0eca88:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_102_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/7934f5523469961ab439c7d52266a332-396960f0029e238a03f6d4a697813729:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_103_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/d32433055070d15967226158d74739a6-30d19e37bfd1404b49e2f38c9ca770c5:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_104_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2fe3d79b07a8548920e0a4bdbf4c1a7a-dabeee7bf5ab201c653101380bcee607:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_105_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/d50cfe390dbdaedfe05bdae8e0fb4b93-1f0b805ed728b39c85453f051b8893aa:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_106_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/bc2718a027a21a071b06b47732b1d892-6317768da383a7d501be79573e6f5815:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_107_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/91234e172f0bf36e892bbc33a2a08320-2fa3f54eb4b50ec9300bbee4ef7feb41:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_108_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/baf493040c36771863b3fc76b0a73ab4-e505aa8e2e78bce8fa00123a8f5eb4fc:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_109_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/d0c36fcabf55fa132862714e45f67710-32f9b4ff33b408c3bd069598c23f2d13:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_110_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/c46a034a13cd5ec1c71bd5d3660b7bf8-57e2af22528fcc901edc3ae64a2cc84a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_111_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/85cdc803d2ecc37dbee1ea121fdb0ee7-e9658f0f45a6179842bb4ca301931db6:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_112_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/04dd5769e2d45d64f3bfd0ddb7b7e870-961b8fb835b1c049ba6025878d6fa6e1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_113_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2b9365cfc7b686a3f866f780d4783dd7-b9da78130e199c363b5a51e143dcfd01:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_114_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/7995a8d19143fcd4c2423fd9df0b297e-a1dc413fded64ef367e730e87d8b4561:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_115_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/9f0d230ff9657a7f2203334d8b9c9836-c5f5091511dee2f977bbd77fcf8806b5:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_116_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/6e3d3ff53f9ff53fa7849f4605b447ff-0b0a781be2eb5b395dd21a3292777881:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_117_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/571cc00d08916eb5f09a7a976e755d6a-08474b51b17f9f9a4a5c2ce586fa9731:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_118_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/0a6dec4b818257f3774dc4e1132c051c-83bd8c7b3936f0797e20a9cb7684b216:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_119_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/af1139aca8f78af1d531ec4380491a09-d3b6862f0a84ac674525cbb37ad79cbb:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_120_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2f1d37b022afc4c6ca38e95d190a7a33-67fd506c195328b38338d44b7d15a1bb:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_121_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/3c0d11a78a2283c2d9c0d458d2cbf503-52f29f956849805dc602b794f063e7b7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_122_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/e4adf44fa73c1b73330140c19927075e-449912da39832a5a365580a7056bc728:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_123_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/cd3999405458eba5c5ff7643f82b6eba-6ecd8390c863739174eeda038282c2f5:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_124_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/f9f91008fb1e234711114aecf57da730-f03dd2bcc53479e012fbaa17260dfd4d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_125_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/3b56541fc019c474ac2b60c1097436c6-08de928f9fd202a4bdc2077a15aa96b5:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_126_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/c129f66316b2aa6d38abd6490131783e-0da55c64eda0efbf58002482b56f436c:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_127_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/cc31503c3ecca6892f743ea9c7f77970-585ef81e64877b0bfe43c8c58f286eef:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_128_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/6e3e670c328b9942b5db2a81146cdaaa-a582354f63d8fd70029595c6a8a10b7a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_129_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4ec3ae9f16b1bdf4d6aee922e02b17b1-eb35ea668b51b491da1006dd1981427a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_130_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4427fb1b580d1981f03ea19f75e33766-c6a3378b534c49eda67350e37746534f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_131_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/fd5b277f070f12cb065df5526fad6cef-b25cb3e4a640263214beb12b9b88dc8b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_132_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/49c0b5ce0daacdd878395fe9fdfcf6bb-45ef383317a6c8edb49ad035a1990d38:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_133_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2db673d4d85b489f318e1ffbbb4e8c6d-8df2b4e18ee0866a655e06f1b1ab0ca2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_134_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/a5ed2d0a3a3a1d4b60b7964cf4312b06-bd8c0043705c089a52b3e43e55946c5e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_135_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/f33af3842735c308c4fc5f6c46a818f2-22df09faaaa9da9ddb6c8c56908f9eb3:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_136_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/976606eff731d1d5f4afb7f107da4f00-953755c5b6a5679e4552cd6bbcb8371f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_137_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/a5c2c2bb213e3f2cfb1f7af4af1b28b2-425509ef0c88ca342503a1aeaa8b92c0:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_138_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/8f989237a2f500c2cb6531f1b84148d8-4a369a08d333ba1bfac2e44eb14c6407:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_139_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2b0f1414626da87d8b8ab8627bb90d5b-e61d07f0cf549f2b3ceeb5ea48fcc6ff:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_140_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/066cb64d46f1e1bca512e0e19ccbe7c5-712408e3b01e75a39070708ecbaca2fe:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_141_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/830838ca82b90b7434557447534dd091-33d2d4d6631ac4dbe58ffe888fc830f9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_142_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2728282680a344970f114e1e269e72a0-ed413274842ef9bcf83208d23e8e1ab1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_143_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/2133d39259db0b5c9253ac5271e2100a-972e9c45ff61b9435294d25d656abb07:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_144_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4dc5801f725da02b6e968a43864dc2cf-c6b3d9648491ee9b227bcf82ada298d2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_145_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/849f0463ea3a51cb7245118f77d2666c-9f240f306acabf660a39d82b16a7b603:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_146_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/66a9e09eb2db6a8738400c2047ed7d31-a7d2086e5b3713e2ccbccb2adafda78e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_147_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/50b933082f687175414b4ff3d73be017-2de4b7a0e21b7a28351db4c598a9ef2a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_148_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/23f0e7e32ecfee9d36d2dcc74995a63c-040764526988d02fb697bf0df567740f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_149_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/de7b5063d06957f32817cb918298bddc-b0c6e88a475383b5330fdf477f4e9db1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_150_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/0bba8ca7826b943b6a8e8fc462c35eaa-54167abdd9b7a929005c268eb867eb2b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_151_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/179c14650e6a93d4525f705d032d8058-90d7dda82a1547b6be89bdecd83ff0a8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_152_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/199acd386a4a565a0ae9290a44836630-c38f69a7783bf551e76289252ef48ae9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_153_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/27cd428f95b317c18510f7fe535d6008-725a51693d2ac1436748b201fff216ff:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_154_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/7d4c66cc31cf3c12194c390f830ed274-b4506be7a688a08ac4a7cbcb10de6d40:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_155_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/c0c0e1a061adfa3a28d236233145b531-35a4b8ed4fbb1fe5a2cdbc9087f7ca2b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_156_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/4e1c8fb6644940246e714854a0217d4b-7bd6eaea1a0bc0a9db7f405618eb41df:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_157_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/1d51d1acaced89a789d44416c2e592c7-73c2b04a1f944b08be869176bc776901:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_158_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/dd67ade56c13e459a63ea59624a29fea-17a96146c1f7b44fb1d92f7b71aacf97:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_159_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/1cffa0038b2beea65d4d7830cd856e66-55cce16fc447a905a87522e1cf28c9aa:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_160_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/e07f0802e09c8e01c53ec2ece0bf646a-b742c4f05e3c16c97c22fe54bb407607:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_161_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/5322368478b5e48d69c9755117b22551-767e4569fecdb81316cc651da8c877b2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_162_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/34b3bbb4f196ed2fa47fd1115860c128-f4985bfeb35eac3171a6f90c0628d620:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_163_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/b09ec6038d5b79a8bf88f14c9b4e391f-a44e25105e081961b748963264f4a8c9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_164_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/fba4cfec6df6a4ef4e12acea0458fe16-a761d9ee148743b003f5564d9ba5f043:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_165_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/77a4e5b2f0da4542f062a0b6169f2265-353696f99887c4c10731cd68065dbb94:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_166_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/c078def2769b8d6a9d53b0e71ad6a171-02233cc18948f81b6d7866ca87640bd9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_167_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/abb00ea6d9ee609ac47d72555cee2e76-75619ea5b296f983ded99b5a86a2f414:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_168_env_data.csv
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-jdawsey/tables/36206d0fb7ee84cd9a96aae37fd12684-ca6c336caa94aac618896a03da2f18b9:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\rgee_test\GEE_LPC\point_data\mesq_location_predictions\poly31\env_batch_csv\poly31_batch_169_env_data.csv
