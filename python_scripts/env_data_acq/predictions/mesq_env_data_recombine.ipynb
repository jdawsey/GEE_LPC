# %%
import os
import pandas as pd
# Out:
# C:\Users\Justin\AppData\Local\Temp\ipykernel_8616\3571106454.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Specify which polygon is being worked on
poly_num = 31

# Define the folder path containing the CSV files
folder_path = f'D:/!!Research/rgee_test/GEE_LPC/point_data/mesq_location_predictions/poly{poly_num}/env_batch_csv'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate through each file in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read the CSV file into a DataFrame
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames in the list into a single DataFrame
merged_df = pd.concat(dfs, ignore_index=True)

# Display or do further processing with the merged DataFrame
merged_df.head()
# Out:
#      bd_0_5   bd_5_15  bd_15_30  bd_30_60  bd_60_100  bd_100_200   clay_0_5  \
# 0  1.306383  1.306879  1.334078  1.363795   1.387891    1.412933  21.127316
# 1  1.306383  1.306879  1.334078  1.363795   1.387891    1.412933  21.127316
# 2  1.454358  1.457852  1.464094  1.451072   1.454492    1.495147  13.006329
# 3  1.464633  1.460966  1.453320  1.441535   1.455502    1.480234  10.663743
# 4  1.500888  1.499941  1.487439  1.471233   1.466367    1.482603   8.158536
#
#    clay_5_15  clay_15_30  clay_30_60  ...  wind_erodibility_index    rf_025  \
# 0  21.565367   21.875000   22.607422  ...              162.640686  0.052762
# 1  21.565367   21.875000   22.607422  ...              166.043564  0.051696
# 2  15.565365   19.579178   18.962063  ...              219.580048  0.009355
# 3  13.128405   18.031250   17.962063  ...              200.078049  0.015609
# 4   9.367188   12.424731   15.085770  ...              180.304001  0.023299
#
# ...

# %%
# Export the merged DataFrame to a CSV file
output_csv_path = f'D:/!!Research/rgee_test/GEE_LPC/point_data/mesq_location_predictions/poly{poly_num}/poly{poly_num}_env_data.csv'
merged_df.to_csv(output_csv_path, index=False)

print("Merged DataFrame has been exported to:", output_csv_path)
# Out:
# Merged DataFrame has been exported to: D:/!!Research/rgee_test/GEE_LPC/point_data/mesq_location_predictions/poly31/poly31_env_data.csv
