# %%
import os
import geopandas as gpd
import pandas as pd
import ee
import geemap
import shp_processor as shp_processor
import image_stack_builder as isb
import gee_data_acq as gda

# %%
# Authenticate to Earth Engine
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
# Authenticate to Earth Engine
#ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create a map using geemap
#m = geemap.Map()
#m

# %%
folder_directory = 'D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction'
bands_csv_name = 'images_and_bands.csv'
images_and_bands = pd.read_csv(f'{folder_directory}/test_mesq_prediction_points/{bands_csv_name}')
images_and_bands.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     collection                                     collection_loc bands  \
# 0     clay_0_5  projects/sat-io/open-datasets/polaris/clay_mea...    b1
# 1    clay_5_15  projects/sat-io/open-datasets/polaris/clay_mea...    b1
# 2   clay_15_30  projects/sat-io/open-datasets/polaris/clay_mea...    b1
# 3   clay_30_60  projects/sat-io/open-datasets/polaris/clay_mea...    b1
# 4  clay_60_100  projects/sat-io/open-datasets/polaris/clay_mea...    b1
#
#    band_rename  base_re unit  resample  resample_res
# 0     clay_0_5       30    m     False           NaN
# 1    clay_5_15       30    m     False           NaN
# 2   clay_15_30       30    m     False           NaN
# 3   clay_30_60       30    m     False           NaN
# 4  clay_60_100       30    m     False           NaN

# %% [markdown]
# ### Adding the directory to the shapefile

# %%
# no slash needed at end of directory
shp_dir = f'{folder_directory}/test_mesq_prediction_points/poly47/fishnet'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#shrubs_states = ['california', 'kansas', 'new_mexico', 'nevada', 'texas']
#sts_abbvs = ['CA', 'KS', 'NM', 'NV', 'TX']
sts_abbrv = ['TX', 'NM']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
other_bands = []

elevation = ee.Image('USGS/3DEP/10m').select(['elevation'])
other_bands.append(elevation)
slope = ee.Terrain.slope(elevation).select(['slope']).rename(['slope'])
other_bands.append(slope)
aspect = ee.Terrain.aspect(elevation).select(['aspect']).rename(['aspect'])
other_bands.append(aspect)

#nhd_area_tx = ee.FeatureCollection(f"projects/sat-io/open-datasets/NHD/NHD_{sts_abbrv[0]}/NHDArea")
#nhd_flowline_tx = ee.FeatureCollection(f"projects/sat-io/open-datasets/NHD/NHD_{sts_abbrv[0]}/NHDFlowline")
#nhd_tx = nhd_area_tx.merge(nhd_flowline_tx)
nhd_area_nm = ee.FeatureCollection(f"projects/sat-io/open-datasets/NHD/NHD_{sts_abbrv[1]}/NHDArea")
nhd_flowline_nm = ee.FeatureCollection(f"projects/sat-io/open-datasets/NHD/NHD_{sts_abbrv[1]}/NHDFlowline")
nhd = nhd_area_nm.merge(nhd_flowline_nm)
#nhd = nhd_tx.merge(nhd_nm)
dist_nhd = nhd.distance(searchRadius=10000, maxError=50) #originally searchRadius = 50000
#dist_nhd = dist_nhd.clip(ee_items[num]) #change clip area
dist_nhd = dist_nhd.select(['distance'])
dist_nhd = dist_nhd.rename('dist_drain')
other_bands.append(dist_nhd)

#roads = ee.FeatureCollection('TIGER/2016/Roads')
#dist_roads = roads.distance(searchRadius=50000, maxError=50)
#dist_roads = dist_roads.select(['distance'])
#dist_roads = dist_roads.rename('dist_road')
#other_bands.append(dist_roads)

print(other_bands)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [<ee.image.Image object at 0x0000019A35F89190>, <ee.image.Image object at 0x0000019A35F8A900>, <ee.image.Image object at 0x0000019A35F8BCE0>, <ee.image.Image object at 0x0000019A35F8A7E0>]

# %%
import re
#roi = ee.FeatureCollection('projects/ee-jdawsey/assets/acc_points_wCoords')
shp_list = []
for file in os.listdir(shp_dir):
    shps = []
    regex_gcs = re.compile(r'[0-9]_gcs+')
    if file.endswith('.shp'):
        shps.append(f'{shp_dir}/{file}')
    for shp in shps:
        if (regex_gcs.search(shp) == None) == True:
            shp_list.append(geemap.shp_to_ee(shp))
        else:
            pass
first_shape = shp_list[0]
shp_list.pop(0)
for shp in shp_list:
    first_shape.merge(shp)


############# need to figure out how to prevent it being a collection of collections
roi = first_shape
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
shp_directory = 'D:/!!Research/!!!Data/ArcGIS_Projects/'
points_dir = f'{shp_directory}/useful_gdbs_and_shps/acc_points/'
#points_name = '....shp'
points_path = f'{points_dir}acc_point_wCoord.shp'
roi = geemap.shp_to_ee(points_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Define a time period
start_date = '2016-06-01'
end_date = '2016-09-30'

# Load Landsat 8 image collection
landsat_collection = ee.ImageCollection('LANDSAT/LC08/C01/T1_SR').filterBounds(roi).filterDate(start_date, end_date).filterMetadata('CLOUD_COVER', 'less_than', 20)

# Function to normalize an image
def normalize(image):
    band_names = image.bandNames()
    min_max = image.reduceRegion(
        reducer=ee.Reducer.minMax(),
        geometry=roi,
        scale=30,
        maxPixels=1e9
    )
    min_dict = ee.Dictionary(min_max.select(band_names.map(lambda band: ee.String(band).cat('_min'))))
    max_dict = ee.Dictionary(min_max.select(band_names.map(lambda band: ee.String(band).cat('_max'))))
    
    def scale_band(band):
        min_val = ee.Number(min_dict.get(ee.String(band).cat('_min')))
        max_val = ee.Number(max_dict.get(ee.String(band).cat('_max')))
        return image.select(band).subtract(min_val).divide(max_val.subtract(min_val))

    scaled_bands = band_names.map(scale_band)
    return ee.Image(scaled_bands).rename(band_names)

# Apply normalization to the collection
normalized_collection = landsat_collection.map(normalize).mosaic()
normalized_collection.bandNames().getInfo()

# Mosaic the normalized collection
#ls_mosaic = normalized_collection.mosaic().clip(roi)

#ls_mosaic.bandNames().getInfo()
"""
#ls_bands = []
for band in ls_mosaic.bandNames().getInfo():
    other_bands.append(ls_mosaic.select(['band']))

#other_bands.append(ls_mosaic)
print(other_bands)
"""
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\data.py:394, in _execute_cloud_call(call, num_retries)
#     393 try:
# --> 394   return call.execute(num_retries=num_retries)
#     395 except googleapiclient.errors.HttpError as e:
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "ImageCollection.mosaic: Error in map(ID=LC08_030037_20160609):
# Image.select, argument 'bandSelectors': Invalid type.
# Expected type: List<Object>.
# Actual type: String.
# Actual value: B1". Details: "ImageCollection.mosaic: Error in map(ID=LC08_030037_20160609):
# Image.select, argument 'bandSelectors': Invalid type.
# Expected type: List<Object>.
# Actual type: String.
# Actual value: B1">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[22], line 30
#      28 # Apply normalization to the collection
#      29 normalized_collection = landsat_collection.map(normalize).mosaic()
# ---> 30 normalized_collection.bandNames().getInfo()
#      32 # Mosaic the normalized collection
#      33 #ls_mosaic = normalized_collection.mosaic().clip(roi)
#      34
#      35 #ls_mosaic.bandNames().getInfo()
#      36 """
#      37 #ls_bands = []
#      38 for band in ls_mosaic.bandNames().getInfo():
#    (...)
#      42 print(other_bands)
#      43 """
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\computedobject.py:107, in ComputedObject.getInfo(self)
#     101 def getInfo(self) -> Optional[Any]:
#     102   """Fetch and return information about this object.
#     103
#     104   Returns:
#     105     The object can evaluate to anything.
#     106   """
# --> 107   return data.computeValue(self)
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\data.py:1093, in computeValue(obj)
#    1090 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1091 _maybe_populate_workload_tag(body)
# -> 1093 return _execute_cloud_call(
#    1094     _get_cloud_projects()
#    1095     .value()
#    1096     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1097 )['result']
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\data.py:396, in _execute_cloud_call(call, num_retries)
#     394   return call.execute(num_retries=num_retries)
#     395 except googleapiclient.errors.HttpError as e:
# --> 396   raise _translate_cloud_exception(e)
#
# EEException: ImageCollection.mosaic: Error in map(ID=LC08_030037_20160609):
# Image.select, argument 'bandSelectors': Invalid type.
# Expected type: List<Object>.
# Actual type: String.
# Actual value: B1

# %%
Map = geemap.Map()
Map

vis_param_gauss = {'bands' : ['b1'], 
               'min' : 0, 
               'max' : 1,
               'gamma' : 1}

Map.addLayer(ls_mosaic, vis_param_gauss)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\data.py:394, in _execute_cloud_call(call, num_retries)
#     393 try:
# --> 394   return call.execute(num_retries=num_retries)
#     395 except googleapiclient.errors.HttpError as e:
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps?fields=name&alt=json returned "ImageCollection.mosaic: Error in map(ID=LC08_030037_20160609):
# Image.select, argument 'bandSelectors': Invalid type.
# Expected type: List<Object>.
# Actual type: String.
# Actual value: B1". Details: "ImageCollection.mosaic: Error in map(ID=LC08_030037_20160609):
# Image.select, argument 'bandSelectors': Invalid type.
# Expected type: List<Object>.
# Actual type: String.
# Actual value: B1">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[18], line 9
#       2 Map
#       4 vis_param_gauss = {'bands' : ['b1'],
#       5                'min' : 0,
#       6                'max' : 1,
#       7                'gamma' : 1}
# ----> 9 Map.addLayer(ls_mosaic, vis_param_gauss)
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\geemap\geemap.py:342, in Map.add_ee_layer(self, ee_object, vis_params, name, shown, opacity)
#     337         if has_plot_dropdown:
#     338             self._plot_dropdown_widget.options = list(
#     339                 self.ee_raster_layers.keys()
#     340             )
# --> 342 super().add_layer(ee_object, vis_params, name, shown, opacity)
#     344 if isinstance(ee_object, (ee.Image, ee.ImageCollection)):
#     345     if has_plot_dropdown:
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\geemap\core.py:754, in Map.add_layer(self, ee_object, vis_params, name, shown, opacity)
#     752 if name is None:
#     753     name = f"Layer {len(self.ee_layers) + 1}"
# --> 754 tile_layer = ee_tile_layers.EELeafletTileLayer(
#     755     ee_object, vis_params, name, shown, opacity
#     756 )
#     758 # Remove the layer if it already exists.
#     759 self.remove(name)
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\geemap\ee_tile_layers.py:144, in EELeafletTileLayer.__init__(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     134 """Initialize the ipyleaflet tile layer.
#     135
#     136 Args:
#    (...)
#     141     opacity (float, optional): The layer's opacity represented as a number between 0 and 1. Defaults to 1.
#     142 """
#     143 self._ee_object = ee_object
# --> 144 self.url_format = _get_tile_url_format(
#     145     ee_object, _validate_vis_params(vis_params)
#     146 )
#     147 super().__init__(
#     148     url=self.url_format,
#     149     attribution="Google Earth Engine",
#    (...)
#     154     **kwargs,
#     155 )
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\geemap\ee_tile_layers.py:19, in _get_tile_url_format(ee_object, vis_params)
#      17 def _get_tile_url_format(ee_object, vis_params):
#      18     image = _ee_object_to_image(ee_object, vis_params)
# ---> 19     map_id_dict = ee.Image(image).getMapId(vis_params)
#      20     return map_id_dict["tile_fetcher"].url_format
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\image.py:129, in Image.getMapId(self, vis_params)
#     127 vis_image, request = self._apply_visualization(vis_params)
#     128 request['image'] = vis_image
# --> 129 response = data.getMapId(request)
#     130 response['image'] = self
#     131 return response
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\data.py:716, in getMapId(params)
#     711 queryParams = {
#     712     'fields': 'name',
#     713     'body': request,
#     714 }
#     715 _maybe_populate_workload_tag(queryParams)
# --> 716 result = _execute_cloud_call(
#     717     _get_cloud_projects()
#     718     .maps()
#     719     .create(parent=_get_projects_path(), **queryParams)
#     720 )
#     721 map_name = result['name']
#     722 url_format = '%s/%s/%s/tiles/{z}/{x}/{y}' % (
#     723     _tile_base_url, _cloud_api_utils.VERSION, map_name)
#
# File ~\miniconda3\envs\gee_env\Lib\site-packages\ee\data.py:396, in _execute_cloud_call(call, num_retries)
#     394   return call.execute(num_retries=num_retries)
#     395 except googleapiclient.errors.HttpError as e:
# --> 396   raise _translate_cloud_exception(e)
#
# EEException: ImageCollection.mosaic: Error in map(ID=LC08_030037_20160609):
# Image.select, argument 'bandSelectors': Invalid type.
# Expected type: List<Object>.
# Actual type: String.
# Actual value: B1

# %%
image_stack_builder = gda.ImageStackBuilder(images_and_bands)
image_stack = image_stack_builder.build_image_stack(other_bands)
print(image_stack.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['clay_0_5', 'clay_5_15', 'clay_15_30', 'clay_30_60', 'clay_60_100', 'clay_100_200', 'sand_0_5', 'sand_5_15', 'sand_15_30', 'sand_30_60', 'sand_60_100', 'sand_100_200', 'silt_0_5', 'silt_5_15', 'silt_15_30', 'silt_30_60', 'silt_60_100', 'silt_100_200', 'bd_0_5', 'bd_5_15', 'bd_15_30', 'bd_30_60', 'bd_60_100', 'bd_100_200', 'om_0_5', 'om_5_15', 'om_15_30', 'om_30_60', 'om_60_100', 'om_100_200', 'ph_0_5', 'ph_5_15', 'ph_15_30', 'ph_30_60', 'ph_60_100', 'ph_100_200', 'ksat_0_5', 'ksat_5_15', 'ksat_15_30', 'ksat_30_60', 'ksat_60_100', 'ksat_100_200', 'theta_r_0_5', 'theta_r_5_15', 'theta_r_15_30', 'theta_r_30_60', 'theta_r_60_100', 'theta_r_100_200', 'theta_s_0_5', 'theta_s_5_15', 'theta_s_15_30', 'theta_s_30_60', 'theta_s_60_100', 'theta_s_100_200', 'caco3', 'cec', 'ec', 'sar', 'kw_025', 'resdept', 'soil_depth', 'wind_erodibility', 'rf_025', 'water_storage', 'ann_rain', 'temp_range', 'elevation', 'slope', 'aspect', 'dist_drain']

# %%
#shp_dir = f'{folder_directory}shp_file'
# Don't need to repeate the folder directory in an fstring, just need to tack on the
# additional directories that lead to the folder you want to store the data in.
# e.g. 'test_mesq_prediction_points/acc_points_env_data/env_data_no_ls'
data_folder = 'test_mesq_prediction_points/poly47/env_data'

shp_data = gda.PointEnvData(folder_directory, data_folder, image_stack, shp_dir)
shp_data.process_shp_files()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Downloading data for 329 files
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/0d49332acb904a12cce5f3d084818a5d-1ba703e9b625571414870ab4aa27a4d7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_0_with_env_data.csv
# Export task started for cell_0.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/fc82af9bf04fb8175051c03a7be1da43-8d7ddefe784f301b70d5f82c03f58cce:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_1_with_env_data.csv
# Export task started for cell_1.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/70d4ed4a0a0e4e1914067146e8a2457d-3fb411401be6aa2c2b4b903f9b7be64b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_2_with_env_data.csv
# Export task started for cell_10.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/9185a506a4cc580906e9ad5e8ab06574-0b65f17a70e5206ff82dcd5410368946:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_3_with_env_data.csv
# Export task started for cell_100.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d52a0af4e78ac75eddee1174b63192a7-c778360a57b5640525e9669bbcbd5d16:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_4_with_env_data.csv
# Export task started for cell_101.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/0ad85181e21f2b015fc747624d6bad2c-d53f68b67b27587839a1804c8ac99d48:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_5_with_env_data.csv
# Export task started for cell_102.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/61c4bd74c7f6edb708adde449cd82b01-c4dc74bb21b94fdb4919379c83dc07d2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_6_with_env_data.csv
# Export task started for cell_103.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/ee6b0d15bfdb5e45151d4e825a87a5d0-0d538fd697d1ae1a558e096e12bf5cc1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_7_with_env_data.csv
# Export task started for cell_104.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/b76a8d36d0a4a205a9427295081f00e3-d534c7ae288b0115ccc6df07a4992ef1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_8_with_env_data.csv
# Export task started for cell_105.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/62ac72884c86e3624fe868661f6ef069-548d08d85cbf84104c0e0c752718bcaf:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_9_with_env_data.csv
# Export task started for cell_106.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/6ad910522079fab6c942e3734e4d914f-84c54c78e4d7bc20a8bc8faa625af803:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_10_with_env_data.csv
# Export task started for cell_107.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/7460beedff6380b8c54177088984b9bb-4d3b0862f93404e6aa0cd534b9759fed:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_11_with_env_data.csv
# Export task started for cell_108.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d7eb0ab1c89459e56853a80d65884a48-c3cbcb8b23bf4750c9e550e07fe60ade:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_12_with_env_data.csv
# Export task started for cell_109.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d528e743d83af2dd1990f2408bd14a60-4b6a490a69706dac20caf901a5d3079a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_13_with_env_data.csv
# Export task started for cell_11.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/297cd3734167e8dbdbcb37369dc7a1f7-855e720fb3adeea99f36ef193c0bf5eb:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_14_with_env_data.csv
# Export task started for cell_110.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/279390a34234a460fd635cb4102c72b2-b00a48adbcf87d5b2287acf98916c6ca:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_15_with_env_data.csv
# Export task started for cell_111.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/7d42ea714308760438d7c2b37a3bcc92-a135ff4a4e2aad990fff5bfa06b0e686:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_16_with_env_data.csv
# Export task started for cell_112.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d460d9518e00b23dda0b00d7e7384f7c-807a7a1f0bf3ec944deb28e506d394ae:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_17_with_env_data.csv
# Export task started for cell_113.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/c04d39eb1048fcd7c2765f1ea24d95c6-13921b966630f7135269d26826534a40:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_18_with_env_data.csv
# Export task started for cell_114.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/ff8ff9db334b9eb59490e945de2d5eb9-c13efa70d6f66e16fa59fd18203e8ee7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_19_with_env_data.csv
# Export task started for cell_115.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/76c736f4c280713b98ac4c780285be27-48887a987984a90081a65ff68cc5cad6:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_20_with_env_data.csv
# Export task started for cell_116.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/78bf2d5b6c1d17360732b0428a829a0f-8322d29a78afa9d95bbbf0ec50eb01dc:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_21_with_env_data.csv
# Export task started for cell_117.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/8104bf29dbeec3dd1cc73bd85baf6708-591b736a4a2ed294d88c7d5736076c2b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_22_with_env_data.csv
# Export task started for cell_118.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/3f6128566cfb85fe89a2fc00963f907d-ccfebb9bff9b0c68cc28abc4e4b22b9f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_23_with_env_data.csv
# Export task started for cell_119.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/8a39ebde08d00779fb82aa4321f7e17d-05234acc34e34b779b0d9f80efe81127:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_24_with_env_data.csv
# Export task started for cell_12.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/22474a0700aa23567935bfd051a89fe9-091145d0aa625d9c2bf46f02c73cc698:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_25_with_env_data.csv
# Export task started for cell_120.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/789d4a5af5504d4f7fc5376abf03b0df-7c8d931bc09a21f5ff8421571d6bb29a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_26_with_env_data.csv
# Export task started for cell_121.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/363474784f096610b9415492a3732e3f-73578a7f62ac801cab911eba03b51f4f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_27_with_env_data.csv
# Export task started for cell_122.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d763774fff0e3129b4cf17ded83ee637-991da046a06d8dd708ca69253842410b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_28_with_env_data.csv
# Export task started for cell_123.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e2b9297372998bf30c97759b5e73ab1b-1cd8f49d07d13d104dbc5e0d17075946:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_29_with_env_data.csv
# Export task started for cell_124.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/bd8f09d1fe3ce38b2d5aa1bc90e99aae-234000d42faa100d42c2d0469ecd8c5d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_30_with_env_data.csv
# Export task started for cell_125.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/24ff825f9b7d55cb78ee7908ef306942-9f9ef92e8d85e9c29cf4caf724238a4b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_31_with_env_data.csv
# Export task started for cell_126.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/7703e7d22fb675d14f3d2b12c8bd4fe0-15be15c3f80f1c5266f95f98d6050c34:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_32_with_env_data.csv
# Export task started for cell_127.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/ca06bc5861da0f0665d7487dd45b82bc-25d4e3c2f9df7cc7691357ee64ec7e8c:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_33_with_env_data.csv
# Export task started for cell_128.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/5c20d6c549ad4601ef46d17e20c73583-443fc94979f0d5798d3b3f82f1ef9327:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_34_with_env_data.csv
# Export task started for cell_129.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/bf8783b4738ffaafa9cd8acf2467d06b-837d778f6909257b11d476debbcc5346:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_35_with_env_data.csv
# Export task started for cell_13.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/0fdddaa51d36b04cc26025cd7bba4dc4-f808c4686df5f22f156a8f59541dc3f1:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_36_with_env_data.csv
# Export task started for cell_130.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/704ee40ddf2db34dd4e9baef539aaf31-419e116b10124295fa02103f74b10602:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_37_with_env_data.csv
# Export task started for cell_131.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e3e3a8d255ba91e00584d296b197d1e5-110b983c771cccc882e97a962265042f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_38_with_env_data.csv
# Export task started for cell_132.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/ab1cb7d76c75c1cc3f5ba4466b8d8bfd-78bc79c3bc787f7a5f42fbc4aa6f7308:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_39_with_env_data.csv
# Export task started for cell_133.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/36fe83d1cd4a460e3ad3716ff65d669f-d8ec89e2ec63014d82de365e85c1f92d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_40_with_env_data.csv
# Export task started for cell_134.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/ad1c91acea7835cb35822cacb46416ae-1b787ff710646ec2934e15964933dc09:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_41_with_env_data.csv
# Export task started for cell_135.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/8abfdc162e8613ed8dfb1fc6fe2a5092-23775b35d319b1332baf2709467cd7f2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_42_with_env_data.csv
# Export task started for cell_136.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/db1313618205d2bfee315b5f2adbfd3d-6e640a49273b0f8536624b34bcf61bc8:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_43_with_env_data.csv
# Export task started for cell_137.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/8f081202bb31e4e51b73f02a5cb49f46-a38c5b5877e425fdcf404c901a67bb69:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_44_with_env_data.csv
# Export task started for cell_138.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d5c1f78480ee968b64e35b9e1ca988d6-d1012850fd257d38b1eb5e907a04f51f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_45_with_env_data.csv
# Export task started for cell_139.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/dac3bd88a645cfe93775d3df0e926dd2-3147ee03a6b96a9eb787e6b033b9b22e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_46_with_env_data.csv
# Export task started for cell_14.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/7f0d1bf40063a1804f81d90fe6060fd9-5f4fedb58ae14145921801692ef5b983:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_47_with_env_data.csv
# Export task started for cell_140.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/fee495d7c9b58ff6266e3b5766cc00c1-497436a2914ff77cd6e2f396cd5a7216:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_48_with_env_data.csv
# Export task started for cell_141.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/c06a250286947ff4b5ca14c59bf846f6-9840bbf56de6c99ec044b36fb016ed88:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_49_with_env_data.csv
# Export task started for cell_142.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/708d7733be82971238181f690e874bb9-0a42a11eaea8ace4e61d680a2540ea06:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_50_with_env_data.csv
# Export task started for cell_143.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/b661639e1b63f381ad8a833c099bd233-c56c0ca605d605435072fa11957ec219:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_51_with_env_data.csv
# Export task started for cell_144.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e2b0f57c5ea8d7cc07d425a537b18306-ed5850abff77b751bc3de11fcc79b749:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_52_with_env_data.csv
# Export task started for cell_145.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/21f39ff38911ca9c1594c7d1f464b2e1-c4500a3a8b233a33d301ef8a10558132:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_53_with_env_data.csv
# Export task started for cell_146.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d95650c19162136f4104a51a4afb16d9-6cd1032c12c491f808704b6b42168794:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_54_with_env_data.csv
# Export task started for cell_147.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/17d261444acc675293b9d78b10ab5d49-579e2cd337123a89e023e3ce164801ae:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_55_with_env_data.csv
# Export task started for cell_148.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/5e218d7fbda0de04de7b31b559abeef8-5549779c09c20160d5ab982dc61c3dd2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_56_with_env_data.csv
# Export task started for cell_149.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e4a8a73ad08a547e5afbd23810ec53e4-f34c445b3cb7e2299e50ae26b9ec54db:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_57_with_env_data.csv
# Export task started for cell_15.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/3468ec7ed2395a9a66f637fe9a80939d-752f2ce0792af6716c1c23165a171521:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_58_with_env_data.csv
# Export task started for cell_150.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/04b1ee01f62f776a54384847054fae03-d27dcdaef0c111bc961ce68b807eb523:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_59_with_env_data.csv
# Export task started for cell_151.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/1b3f82a2a91832d6e05cd044317865dc-da7f2aa52ae9acd86b1b53fd0a10a11f:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_60_with_env_data.csv
# Export task started for cell_152.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/4d091351e424c06630209fca9783f1e8-8ab87bf438e48b89f641b7b4d85af00b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_61_with_env_data.csv
# Export task started for cell_153.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/fb3b229d135add8ff6e4cad313fc04e1-cdaf6690468fc0b8e4e40ad781d1ee5e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_62_with_env_data.csv
# Export task started for cell_154.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/7910a1289d5d88c23f2be70fa5ea147b-53a26b2165bd48d9f6df5619f7d33476:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_63_with_env_data.csv
# Export task started for cell_155.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/fdbd874fff9514afb2125a5b6c6a7ccc-c94382956d48de8f26c35e4215ddf242:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_64_with_env_data.csv
# Export task started for cell_156.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/03bc1d6549dac3c91fc8b9b8127670d5-9c6385d59c8a405e01d5b216479147ee:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_65_with_env_data.csv
# Export task started for cell_157.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d31468da622f8d95fbeb4f706f2edba9-f7fd4c3cb77940188b73c6fbbd63d0ee:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_66_with_env_data.csv
# Export task started for cell_158.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/906ca29150ea9b651f5df2a3cec4d428-2cc8b0ca4e274bfde3516544df5dd43c:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_67_with_env_data.csv
# Export task started for cell_159.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/608459fedbdbf53a491c3ec30632698a-99caacad973f4a3064f1e7cc2dbfe0fd:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_68_with_env_data.csv
# Export task started for cell_16.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/26907045d89c15c2542ddfd75d2345fa-80eb8a4c607baff2fa10bd657742ab48:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_69_with_env_data.csv
# Export task started for cell_160.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/835095fdaecacd4e5e2677ed190a1b88-4d13e04dccbb15c78313acf7622e5222:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_70_with_env_data.csv
# Export task started for cell_161.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/a5f62ab5ad6722173b0208402567e370-d4c2772d33f49c3c3760bc3caedd7f9a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_71_with_env_data.csv
# Export task started for cell_162.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/4f291122409d48f82a97760d016da03b-86c0f699dd07ab43af0bd4bb0bd10b53:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_72_with_env_data.csv
# Export task started for cell_163.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/150c52afdb90295508deed59f692ead1-26dd5fbe0e790a41d436da39607bd6f2:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_73_with_env_data.csv
# Export task started for cell_164.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/673e102610fc31f6fbd150c4c82e9ff6-fb8ba7daed7102398eefad8ac03a258d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_74_with_env_data.csv
# Export task started for cell_165.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/40e859766b3a7b1ebc1dc6ffcc06ffb5-c1abeab5214de71ac35d95515d01d73b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_75_with_env_data.csv
# Export task started for cell_166.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/8ca80f17826c5d5adfad10138fa6e31c-45fcf8115701a5fb01a8d1ce1a2812d0:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_76_with_env_data.csv
# Export task started for cell_167.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/1cb8797ccc3ca1aa5efd1cd3037aa171-63941d83238a1caf4b41a1c62953d5fe:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_77_with_env_data.csv
# Export task started for cell_168.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/4f66d477c3cf917f62396710c6cf42e2-cb44a24fe9fe395cf563991257818abd:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_78_with_env_data.csv
# Export task started for cell_169.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/358150ca684a25410f55e378dbaf7cec-9455ba0f3d5ad8ac83a8b72dcd68b305:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_79_with_env_data.csv
# Export task started for cell_17.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/41abe7b552566bbabffd73021ce04eba-9b4cf7daf2219af38889d167b01e1a8d:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_80_with_env_data.csv
# Export task started for cell_170.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e59b001d57682bb1def7a9538c88e9a8-f391975564f126f15d80a736f46f55c7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_81_with_env_data.csv
# Export task started for cell_171.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/454620536df854e3d7ffa7b42518748e-5dd4ee230d439f042fd202bc5ec6d75e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_82_with_env_data.csv
# Export task started for cell_172.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/a79ac9c8c6e2b33f59d4e906aadee6ab-49852b80501cef678616b3d5ee45af42:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_83_with_env_data.csv
# Export task started for cell_173.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/6529c47620ab4cafe6b90108837734e2-a86a122793a94c736edc6ecba87bead6:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_84_with_env_data.csv
# Export task started for cell_174.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e673f21bcdfd18150e198cd0e169bd3a-ac17b280465e0493788c0ae21f4aaffc:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_85_with_env_data.csv
# Export task started for cell_175.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e92ca67b904cbc972b8048a06f283759-b7cd49933cd4907a508c2ec44cef1e2e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_86_with_env_data.csv
# Export task started for cell_176.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/ebc5aad8e0a59f28081e781e60f41165-de5af594f837890c84a6dd6863ed7c40:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_87_with_env_data.csv
# Export task started for cell_177.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d57aef3897647fdba68b0606a2092bad-63c649e5f4e1d57088d67e6e09dacba7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_88_with_env_data.csv
# Export task started for cell_178.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/3d2932bc2fc85722bb4070c39eac8ceb-0f140346f68be281ea1fb10e23e7990e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_89_with_env_data.csv
# Export task started for cell_179.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/10b6540ec2bf295ed30fff935d9810b0-b724d3a42faea9c15748a4441da4cf57:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_90_with_env_data.csv
# Export task started for cell_18.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/6b5a09d5e8780e82ca00dcf15888e2f8-4f112bdd10ad55d6e24af61a4a916ace:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_91_with_env_data.csv
# Export task started for cell_180.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/dba87a63dfac225e3238fd2e939bf67e-9d852305f8a906980d4f04b997a32cf0:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_92_with_env_data.csv
# Export task started for cell_181.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/3f663dcc5d13bfd30611c221e35ade16-895e8b994bfb4739bd97ac0143059286:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_93_with_env_data.csv
# Export task started for cell_182.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/a729b7db56246c4be6074420e085c011-862a9d8c12f434c5f2849e7943b77878:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_94_with_env_data.csv
# Export task started for cell_183.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/20f7f7eebdf480521f052b0d7fec2293-b00d41b655fc2d8760b65eeae5518d19:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_95_with_env_data.csv
# Export task started for cell_184.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/2d1a8ddc1ca18935094d7c3f9f917b6e-3fbb0fcd7d0146a6948bbe96765474ae:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_96_with_env_data.csv
# Export task started for cell_185.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/1ce05b5a1b56fe2925c2b1588c999bf1-c56b9817a215e633a78f66d8a97e2703:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_97_with_env_data.csv
# Export task started for cell_186.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/2b6acd24f2a9c8b4d08f3d96129967e0-630dd9894dd52bba15e7dd380d21d760:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_98_with_env_data.csv
# Export task started for cell_187.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/9929dd02aedec8762d31d328054ab255-e00e53f27b2df00279985140ad401556:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_99_with_env_data.csv
# Export task started for cell_188.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/ba6a8032fe776e6d750e6b8779e391e1-ce367de77883486ac6628b4368755e8e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_100_with_env_data.csv
# Export task started for cell_189.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/0fe2ed496f5f24652fd4db7312a099e3-a23e713438a41891a1fdf04cc2f9244e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_101_with_env_data.csv
# Export task started for cell_19.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/a0e0ae4d891d467123ddb06dae89acfd-5bb7952cf0e127ea5a549912d865c5bb:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_102_with_env_data.csv
# Export task started for cell_190.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/2315a0ebf33e71e3e1377db27f340d4c-30f0d93b19952e8ba214eda71a66a237:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_103_with_env_data.csv
# Export task started for cell_191.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/aa54f33e85d9ad3faecb357e39e0573f-73f3e5c238cf936d1499c52b2df2707b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_104_with_env_data.csv
# Export task started for cell_192.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/366717163e575d402a17be60e951b109-4e6126bbd0d481e49b89afd39e56226a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_105_with_env_data.csv
# Export task started for cell_193.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/211f5ec8498bc1327a5e8545c8a65c38-271ba0192bcc97a79613593e0d669d1a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_106_with_env_data.csv
# Export task started for cell_194.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/e2a6a69b12442d3c72ae785f6f3c4cf9-cb18161c9090882ce76bd11abd502660:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_107_with_env_data.csv
# Export task started for cell_195.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/b07006d94f05ffe26275e8b9719ed97f-f00f2384a6be4ed7239caf0d846254d0:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_108_with_env_data.csv
# Export task started for cell_196.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/359b057824bdbc71f9fb27f8fa63ba97-e91701022a18573baef2f5d0a3c14d37:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_109_with_env_data.csv
# Export task started for cell_197.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/cad9788ed3094800b7c47d56b9c28b2b-7def97d280f972e3d85ea8da784c0a0a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_110_with_env_data.csv
# Export task started for cell_198.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/69839e0828cd3aefff41687c32d7da35-2cc7af7acc53b3f55d95e1a345985520:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_111_with_env_data.csv
# Export task started for cell_199.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/6e44633a9079a9bea9904cdfcc046e9f-58506da3fee15bb8835676024c0a6715:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_112_with_env_data.csv
# Export task started for cell_2.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/77506b1601ba44ff3206a288750159c8-1bc4c94f615e51b334bb446d92f3c0ec:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_113_with_env_data.csv
# Export task started for cell_20.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/81a5ef419c25f7b7fe7c05d4d1cc7b95-f5a653d9f5d55441ed3b5218a0ec836c:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_114_with_env_data.csv
# Export task started for cell_200.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/2dbeb13fb168c9c76ca3436353e61ec0-ab5fe1a4db171a5cae336698193d076b:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_115_with_env_data.csv
# Export task started for cell_201.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/3d4541e46e0879e2d796f06b23ac6be1-e1335e907bafdebb2ae032aaeaa16315:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_116_with_env_data.csv
# Export task started for cell_202.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/0483f864775b53c0c2c9781313541efc-a7cef914180293c0cd8fb3734ceb8f9a:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_117_with_env_data.csv
# Export task started for cell_203.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/d9e9397d5f93d4c5f3894f794502d8d6-33240b6bba81e06ac0c49589a417174e:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_118_with_env_data.csv
# Export task started for cell_204.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/b3a64fa915671ac6c11bd8aca4ed9b6e-e4afb8aa55d084346f16ed396ea984a7:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_119_with_env_data.csv
# Export task started for cell_205.shp.
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/earthengine-legacy/tables/7cec8a826da3f0a79410c2f5f1385be2-cbf15e415b1e9e75812331b0b18ca4a6:getFeatures
# Please wait ...
# Data downloaded to D:\!!Research\!!!Data\ArcGIS_Projects\mesq_prediction\test_mesq_prediction_points\poly47\env_data\cell_120_with_env_data.csv
# Export task started for cell_206.shp.
# Generating URL ...
# ...
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_76_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_76_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_77_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_77_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_77_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_77_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_77_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_78_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_78_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_78_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_78_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_78_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_79_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_79_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_79_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_79_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_79_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_7_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_7_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_7_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_7_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_7_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_80_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_80_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_80_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_80_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_80_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_81_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_81_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_81_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_81_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_81_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_82_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_82_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_82_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_82_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_82_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_83_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_83_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_83_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_83_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_83_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_84_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_84_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_84_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_84_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_84_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_85_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_85_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_85_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_85_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_85_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_86_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_86_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_86_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_86_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_86_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_87_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_87_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_87_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_87_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_87_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_88_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_88_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_88_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_88_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_88_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_89_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_89_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_89_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_89_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_89_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_8_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_8_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_8_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_8_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_8_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_90_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_90_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_90_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_90_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_90_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_91_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_91_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_91_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_91_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_91_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_92_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_92_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_92_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_92_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_92_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_93_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_93_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_93_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_93_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_93_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_94_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_94_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_94_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_94_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_94_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_95_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_95_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_95_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_95_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_95_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_96_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_96_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_96_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_96_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_96_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_97_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_97_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_97_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_97_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_97_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_98_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_98_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_98_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_98_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_98_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_99_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_99_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_99_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_99_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_99_gcs.shx
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_9_gcs.cpg
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_9_gcs.dbf
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_9_gcs.prj
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_9_gcs.shp
# removed D:/!!Research/!!!Data/ArcGIS_Projects/mesq_prediction/test_mesq_prediction_points/poly47/fishnet/cell_9_gcs.shx
